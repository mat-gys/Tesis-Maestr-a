# %%
# Folder where demos are stored
path_to_demos = "..\\input"
# Folder to output dataframe
output = "..\\output"
# Folder with txt file for demos to view
path_to_txt = "..\\Demos_a_revisar.txt"

# %% [markdown]
# # Functions to generate frame states

# %%
# Although I have made some minor modifications, this part of the code was given to me by Peter Xenopoulos
import lzma
import json

# Function to read .xz archives from ESTA
def read_parsed_demo(filename):
  with lzma.LZMAFile(filename, "rb") as f:
    d = json.load(f)
    return d

def generate_vector_state(frame, map_name):
    """Returns a game state in a dictionary format.

    Args:
        frame (dict) : Dict output of a frame generated from the DemoParser class
        map_name (string): String indicating the map name

    Returns:
        A dict with keys for each feature.
    """
    game_state = {}
    game_state["mapName"] = map_name
    game_state["secondsSincePhaseStart"] = frame["seconds"]
    game_state["bombPlanted"] = frame["bombPlanted"]
    game_state["bombsite"] = frame["bombsite"]
    game_state["totalSmokes"] = len(frame["smokes"])
    game_state["totalFires"] = len(frame["fires"])

    # Team specific info (CT)
    game_state["ctAlive"] = 0
    game_state["ctHp"] = 0
    game_state["ctArmor"] = 0
    game_state["ctHelmet"] = 0
    game_state["ctEq"] = 0
    game_state["ctUtility"] = 0
    game_state["ctEqValStart"] = 0
    game_state["ctBombZone"] = 0
    game_state["defusers"] = 0
    game_state["ctNone"] = 0
    game_state["ctCash"] = 0
    if frame["ct"]["players"] != None:
        for p in frame["ct"]["players"]:
            game_state["ctEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["ctCash"] += p["cash"]
            if p["isAlive"]:
                game_state["ctAlive"] += 1
                game_state["ctHp"] += p["hp"]
                game_state["ctArmor"] += p["armor"]
                game_state["ctHelmet"] += p["hasHelmet"]
                game_state["ctEq"] += p["equipmentValue"]
                game_state["ctUtility"] += p["totalUtility"]
                game_state["defusers"] += p["hasDefuse"]
                if p["isInBombZone"]:
                    game_state["ctBombZone"] += 1
    else: 
        game_state["ctNone"] = 1

    # Team specific info (T)
    game_state["tAlive"] = 0
    game_state["tHp"] = 0
    game_state["tArmor"] = 0
    game_state["tHelmet"] = 0
    game_state["tEq"] = 0
    game_state["tUtility"] = 0
    game_state["tEqValStart"] = 0
    game_state["tHoldingBomb"] = 0
    game_state["tBombZone"] = 0
    game_state["tNone"] = 0
    game_state["tCash"] = 0
    if frame["t"]["players"] != None:
        for p in frame["t"]["players"]:
            game_state["tEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["tCash"] += p["cash"]
            if p["isAlive"]:
                game_state["tAlive"] += 1
                game_state["tHp"] += p["hp"]
                game_state["tArmor"] += p["armor"]
                game_state["tHelmet"] += p["hasHelmet"]
                game_state["tEq"] += p["equipmentValue"]
                game_state["tUtility"] += p["totalUtility"]
                if p["isInBombZone"]:
                    game_state["tBombZone"] += 1
                if p["hasBomb"]:
                    game_state["tHoldingBomb"] = 1
    else: 
        game_state["tNone"] = 1

    return game_state

# %% [markdown]
# # Via json files

# %%
# Folder where demos are stored
#path_to_demos = "C:\\Users\\Matias\\Downloads\\esta\\data\\online"
path_to_demos = "..\\input"
path_to_json = "..\\jsons"
# Folder to output dataframe
output = "..\\output"
# Folder with txt file for demos to view
path_to_txt = "..\\Demos_a_revisar.txt"

# %%
'''
Parsing games, compressing json file, compressing it and deleting .dem files
'''
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os, shutil
import patoolib
import zipfile
from zipfile import ZipFile

os.chdir(path_to_demos)

# Main dataframe
round_state_df = pd.DataFrame()

carpetas = []
for file in os.listdir():
    if ".rar" in file:
        patoolib.extract_archive("%s" % file, outdir="%s" %path_to_demos)

    # Grab demo names
    demos = []
    for demo in os.listdir():
        if (".dem" in demo) and (demo[0]!="x"):
            os.rename(demo, "x" + file.split("vs")[0] + "vs" + demo.split("vs")[1])
            demos += ["x" + file.split("vs")[0] + "vs" + demo.split("vs")[1]]
        if ".json" in demo:
            os.remove(demo)
            
    ### Itero parser over demos
    for demo in demos:
        demo_parser = DemoParser(
        demofile = "%s" % demo,
        parse_rate=128, 
        buy_style="hltv",
        parse_chat = True
        )
    
        try:
            # Parse the demofile, output results to dictionary
            df = demo_parser.parse(return_type="json")
    
            print(f"{demo[1:-4]}")
            os.remove(demo)
            shutil.move(f'x{demo[1:-4]}.json', f"{path_to_json}")
            
        except Exception as e:
            print(e)
            continue
    
    os.remove(file)
# Out:
# patool: Extracting DreamHack-Masters-Winter-2020-Europe-gambit-vs-astralis-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\DreamHack-Masters-Winter-2020-Europe-gambit-vs-astralis-bo3.rar"
# patool:     with cwd=..\input
# patool: ... DreamHack-Masters-Winter-2020-Europe-gambit-vs-astralis-bo3.rar extracted to `..\input'.
# DreamHack-Masters-Winter-2020-Europe-gambit-vs-astralis-m1-vertigo
# DreamHack-Masters-Winter-2020-Europe-gambit-vs-astralis-m2-inferno
# patool: Extracting DreamHack-Masters-Winter-2020-Europe-gambit-vs-complexity-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\DreamHack-Masters-Winter-2020-Europe-gambit-vs-complexity-bo3.rar"
# patool:     with cwd=..\input
# patool: ... DreamHack-Masters-Winter-2020-Europe-gambit-vs-complexity-bo3.rar extracted to `..\input'.
# DreamHack-Masters-Winter-2020-Europe-gambit-vs-complexity-m1-train
# DreamHack-Masters-Winter-2020-Europe-gambit-vs-complexity-m2-mirage
# patool: Extracting DreamHack-Masters-Winter-2020-Europe-heroic-vs-spirit-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\DreamHack-Masters-Winter-2020-Europe-heroic-vs-spirit-bo3.rar"
# patool:     with cwd=..\input
# patool: ... DreamHack-Masters-Winter-2020-Europe-heroic-vs-spirit-bo3.rar extracted to `..\input'.
# DreamHack-Masters-Winter-2020-Europe-heroic-vs-spirit-m1-mirage
# DreamHack-Masters-Winter-2020-Europe-heroic-vs-spirit-m2-nuke
# patool: Extracting DreamHack-Masters-Winter-2020-Europe-liquid-vs-astralis-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\DreamHack-Masters-Winter-2020-Europe-liquid-vs-astralis-bo3.rar"
# patool:     with cwd=..\input
# patool: ... DreamHack-Masters-Winter-2020-Europe-liquid-vs-astralis-bo3.rar extracted to `..\input'.
# DreamHack-Masters-Winter-2020-Europe-liquid-vs-astralis-m1-vertigo
# DreamHack-Masters-Winter-2020-Europe-liquid-vs-astralis-m2-inferno
# patool: Extracting Flashpoint-2-fnatic-vs-og-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\Flashpoint-2-fnatic-vs-og-bo3.rar"
# patool:     with cwd=..\input
# patool: ... Flashpoint-2-fnatic-vs-og-bo3.rar extracted to `..\input'.
# Flashpoint-2-fnatic-vs-og-m1-mirage
# Flashpoint-2-fnatic-vs-og-m2-overpass
# patool: Extracting Flashpoint-2-virtus-pro-vs-big-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\Flashpoint-2-virtus-pro-vs-big-bo3.rar"
# patool:     with cwd=..\input
# patool: ... Flashpoint-2-virtus-pro-vs-big-bo3.rar extracted to `..\input'.
# Flashpoint-2-virtus-pro-vs-big-m1-mirage
# Flashpoint-2-virtus-pro-vs-big-m2-vertigo
# Flashpoint-2-virtus-pro-vs-big-m3-overpass
# patool: Extracting Flashpoint-2-virtus-pro-vs-fnatic-bo3.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Documents\UDESA\Tesis_maestria\Replication files\input\Flashpoint-2-virtus-pro-vs-fnatic-bo3.rar"
# patool:     with cwd=..\input
# patool: ... Flashpoint-2-virtus-pro-vs-fnatic-bo3.rar extracted to `..\input'.
# Flashpoint-2-virtus-pro-vs-fnatic-m1-vertigo
# Flashpoint-2-virtus-pro-vs-fnatic-m2-overpass
# Flashpoint-2-virtus-pro-vs-fnatic-m3-train

# %%
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os, shutil
import patoolib
import json
import lzma


os.chdir("..\\jsons")

# Main dataframe
round_state_df = pd.DataFrame()

# Grab demo names
demos = []
for demo in os.listdir():
    if ".json" in demo:
        print(f"{demo}")
        with open(demo, encoding="utf-8") as demo_json:
                df = json.load(demo_json)
        #with open(demo, encoding = 'Latin-1') as f:
        #    df = json.load(f)
    # Grab round end frames (last frame of every round)
        frames = []
        iteration = 1
        for ronda in df["gameRounds"]:
            for f in ronda["frames"]:
                if f["clockTime"] == "01:55":
                    frames.append(ronda["frames"][-1])
                    break
        mapa = df["mapName"]
        
    
        # Generate vectors for each frame and pass them to df
        states = []
        for f in frames:
            game_state = generate_vector_state(f, mapa)
            states.append(game_state)
        states = pd.DataFrame(states)
        states["matchID"] = (demo[:-4])
        
        try:
            # Get total freeze time
            freezeTimeEnd = []
            startTick = []
            ctTeam = []
            tTeam = []
            winningSide = []
            for round in df["gameRounds"]:
                freezeTimeEnd.append(round["freezeTimeEndTick"])
                startTick.append(round["startTick"])
                ctTeam.append(round["ctTeam"])
                tTeam.append(round["tTeam"])
                winningSide.append(round["winningSide"])

            states["freezeTimeEndTick"] = freezeTimeEnd
            states["startTick"] = startTick
            states["ctTeam"] = ctTeam
            states["tTeam"] = tTeam
            states["winningSide"] = winningSide
            states["freezeTimeTotal"] = states["freezeTimeEndTick"] - states["startTick"] 
            states["pause"] = 0
            states["player"] = ""
            states["msg"] = ""

            # Iterate over messages, if they include a mention of a pause (either include word "pause" or "tech"), then:
            #    If msgtick >= freezeTimeEndTick ==> pause = 1 in current roundnum + 1

            for msg in df['chatMessages']:

                if msg['params'] is not None:
                    if "tech" in msg["text"] or "pause" in msg["text"]:
                        print(f'There was a pause called by {msg["params"][0]}:  {msg["text"]} at tick {msg["tick"]}' )
                        index = states.index[states["freezeTimeEndTick"]>=msg["tick"]][0]
                        if states["pause"].loc[index] == 0:
                            states.loc[index, "pause"] = 1
                            states.loc[index, "player"] = msg["params"][0]
                            states.loc[index, "msg"] = msg["text"]
                            
                if msg['params'] is None:
                    if "A player disconnected, auto pausing." in msg["text"] or "Waiting for both teams and admin to ready to continue." in msg["text"]:
                        index = states.index[states["freezeTimeEndTick"]>=msg["tick"]][0]
                        if states["pause"].loc[index] == 0:
                            states.loc[index, "pause"] = 1
                            states.loc[index, "player"] = "Admin"
                            states.loc[index, "msg"] = msg["text"]
                        
                            
            for i in range(0,5):
                states[f"ct_p{i+1}"] = ""
                states[f"t_p{i+1}"] = ""   
                states.loc[0:15, f"ct_p{i+1}"] = df["gameRounds"][0]["ctSide"]["players"][i]["playerName"]
                states.loc[0:15, f"t_p{i+1}"]  = df["gameRounds"][0]["tSide"]["players"][i]["playerName"]
                states.loc[15:, f"ct_p{i+1}"]  = df["gameRounds"][0]["tSide"]["players"][i]["playerName"]
                states.loc[15:, f"t_p{i+1}"]  = df["gameRounds"][0]["ctSide"]["players"][i]["playerName"]

        except:
            states["mismatch"] = 0
            
            for msg in df['chatMessages']:

                if msg['params'] is not None:
                    if "tech" in msg["text"] or "pause" in msg["text"]:
                        states.loc[:, "mismatch"] = 1
        
        round_state_df = pd.concat([round_state_df, pd.DataFrame(states)])
        
round_state_df.reset_index(inplace = True)
round_state_df["roundNum"] = round_state_df["index"] + 1
round_state_df.drop("index", axis = 1, inplace = True)

with pd.ExcelWriter(
    f"{output}\\parsed.xlsx",
    mode = "w",
    engine = "xlsxwriter"
) as writer:
    round_state_df.to_excel(writer, index = False, startrow = 0, header = True)
# Out:
# xAmericas-Minor-StarLadder-Major-2019-nrg-vs-furia-m1-train.json
# There was a pause called by Stanislaw:  !pause at tick 134587
# There was a pause called by Stanislaw:  !unpause at tick 137021
# There was a pause called by arT:  !unpause at tick 138276
# xAmericas-Minor-StarLadder-Major-2019-nrg-vs-furia-m2-nuke.json
# There was a pause called by Stanislaw:  !pause at tick 196220
# There was a pause called by Stanislaw:  tech at tick 196362
# There was a pause called by Stanislaw:  !unpause at tick 201732
# There was a pause called by arT:  .unpause at tick 202459
# xbetboom-playlist-urbanistic-2023-cloud9-vs-forze-m1-mirage.json
# xbetboom-playlist-urbanistic-2023-cloud9-vs-forze-m2-inferno.json
# xbetboom-playlist-urbanistic-2023-mouz-vs-forze-m1-overpass.json
# xbetboom-playlist-urbanistic-2023-mouz-vs-forze-m2-ancient.json
# xbetboom-playlist-urbanistic-2023-virtuspro-vs-forze-m1-overpass.json
# xbetboom-playlist-urbanistic-2023-virtuspro-vs-forze-m2-anubis.json
# xBLAST-Premier-Fall-2020-Finals-natus-vincere-vs-astralis-m1-inferno.json
# There was a pause called by electronic:  .tech at tick 181595
# There was a pause called by electronic:  !pause at tick 181931
# xBLAST-Premier-Fall-2020-Finals-natus-vincere-vs-astralis-m2-nuke.json
# There was a pause called by Perfecto:  .tech at tick 19385
# There was a pause called by Perfecto:  !tech at tick 19765
# There was a pause called by device:  .tech at tick 30275
# There was a pause called by Magisk:  !tech at tick 30404
# There was a pause called by Magisk:  .tech at tick 30729
# There was a pause called by s1mple:  !pause at tick 31345
# There was a pause called by device:  u type !pause at tick 41671
# There was a pause called by electronic:  !pause at tick 42192
# There was a pause called by flamie:  .unpause at tick 42225
# There was a pause called by s1mple:  !unpause at tick 42239
# There was a pause called by electronic:  !pause at tick 454086
# There was a pause called by electronic:  !pause at tick 454925
# xBLAST-Premier-Fall-2020-Finals-natus-vincere-vs-astralis-m3-dust2.json
# xBLAST-Premier-Fall-2020-Finals-og-vs-big-m1-dust2.json
# xBLAST-Premier-Fall-2020-Finals-og-vs-big-m2-inferno.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-astralis-m1-vertigo.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-astralis-m2-dust2.json
# There was a pause called by shox :  !pause at tick 300786
# There was a pause called by apEX:  .tech at tick 300827
# There was a pause called by apEX:  !pause at tick 344974
# There was a pause called by Nivera:  :pause at tick 346838
# There was a pause called by device:  !pause at tick 347107
# There was a pause called by dupreeh:  Im always a troll when theres pauses at tick 400831
# There was a pause called by Xyp9x:  !pause at tick 408538
# There was a pause called by device:  !pause at tick 408574
# There was a pause called by apEX:  !pause at tick 409374
# There was a pause called by shox :  !pause at tick 536077
# There was a pause called by zonic'10 -.-:  !pause at tick 541724
# There was a pause called by Xyp9x:  you need to !pause at tick 541959
# There was a pause called by shox :  !pause at tick 542034
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-astralis-m3-inferno.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-big-m1-vertigo.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-big-m2-inferno.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-big-m3-dust2.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-mousesports-m1-inferno.json
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-mousesports-m2-dust2.json
# There was a pause called by shox :  .tech at tick 63647
# There was a pause called by shox :  .pause at tick 64138
# There was a pause called by shox :  !tech at tick 64387
# There was a pause called by shox :  !pause at tick 64708
# There was a pause called by chrisJ:  .tech at tick 64827
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-natus-vincere-m1-nuke.json
# There was a pause called by Boombl4:  !pause at tick 393314
# There was a pause called by Perfecto:  !pause at tick 393326
# There was a pause called by flamie:  !unpause at tick 397758
# There was a pause called by electronic:  !pause at tick 398083
# xBLAST-Premier-Fall-2020-Finals-vitality-vs-natus-vincere-m2-dust2.json
# There was a pause called by Perfecto:  !pause at tick 22190
# There was a pause called by s1mple:  tech at tick 22516
# There was a pause called by electronic:  .tech at tick 22866
# xBLAST-Premier-Fall-Final-2021-astralis-vs-faze-m1-mirage.json
# xBLAST-Premier-Fall-Final-2021-astralis-vs-faze-m2-nuke.json
# xBLAST-Premier-Fall-Final-2021-astralis-vs-faze-m3-dust2.json
# xBLAST-Premier-Fall-Final-2021-astralis-vs-heroic-m1-mirage.json
# xBLAST-Premier-Fall-Final-2021-astralis-vs-heroic-m2-nuke.json
# xBLAST-Premier-Fall-Final-2021-faze-vs-big-m1-dust2.json
# There was a pause called by karrigan:  .tech at tick 1562
# There was a pause called by karrigan:  .tech at tick 287819
# There was a pause called by karrigan:  !tech at tick 288549
# There was a pause called by karrigan:  .tech at tick 288971
# There was a pause called by karrigan:  !tech at tick 289443
# There was a pause called by karrigan:  .tech at tick 289645
# There was a pause called by rain :  !pause at tick 289937
# There was a pause called by rain :  !pause at tick 295533
# xBLAST-Premier-Fall-Final-2021-faze-vs-big-m2-inferno.json
# xBLAST-Premier-Fall-Final-2021-heroic-vs-faze-m1-mirage.json
# There was a pause called by refrezh:  .tech at tick 3132
# There was a pause called by refrezh:  !tech at tick 3450
# There was a pause called by karrigan:  .tech at tick 116457
# There was a pause called by rain :  .tech at tick 116531
# There was a pause called by rain :  !pause at tick 116821
# There was a pause called by karrigan:  !tech at tick 116884
# xBLAST-Premier-Fall-Final-2021-heroic-vs-faze-m2-nuke.json
# xBLAST-Premier-Fall-Final-2021-heroic-vs-liquid-m1-overpass.json
# There was a pause called by FalleN:  .tech at tick 390827
# xBLAST-Premier-Fall-Final-2021-heroic-vs-liquid-m2-nuke.json
# xBLAST-Premier-Fall-Final-2021-heroic-vs-liquid-m3-inferno.json
# xBLAST-Premier-Fall-Final-2021-heroic-vs-natus-vincere-m1-inferno.json
# There was a pause called by electronic:  !pause at tick 153198
# There was a pause called by electronic:  !pause at tick 156892
# There was a pause called by cadiaN:  !pause at tick 236419
# xBLAST-Premier-Fall-Final-2021-heroic-vs-natus-vincere-m2-mirage.json
# There was a pause called by electronic:  !pause at tick 374800
# There was a pause called by electronic:  !pause at tick 376684
# xBLAST-Premier-Fall-Final-2021-heroic-vs-natus-vincere-m3-overpass.json
# xBLAST-Premier-Fall-Final-2021-natus-vincere-vs-big-m1-dust2.json
# xBLAST-Premier-Fall-Final-2021-natus-vincere-vs-big-m2-nuke.json
# There was a pause called by electronic:  .tech at tick 35981
# There was a pause called by b1t:  .tech at tick 36050
# There was a pause called by electronic:  !pause at tick 36211
# There was a pause called by s1mple:  !unpause at tick 109069
# There was a pause called by s1mple:  !pause at tick 109268
# There was a pause called by electronic:  !pause at tick 109306
# There was a pause called by syrsoN:  !pause at tick 110697
# xBLAST-Premier-Fall-Final-2021-natus-vincere-vs-vitality-m1-inferno.json
# There was a pause called by s1mple:  !pause at tick 26332
# There was a pause called by apEX:  !pause at tick 102935
# There was a pause called by apEX:  tech at tick 103322
# xBLAST-Premier-Fall-Final-2021-natus-vincere-vs-vitality-m1-mirage.json
# There was a pause called by apEX:  .tech at tick 1424
# There was a pause called by apEX:  !pause at tick 1643
# There was a pause called by shox :  !technical at tick 14805
# There was a pause called by apEX:  !pause at tick 14831
# There was a pause called by apEX:  tech at tick 15150
# There was a pause called by ZywOo:  !pause at tick 346040
# There was a pause called by misutaaa:  tech at tick 346672
# There was a pause called by ZywOo:  !pause  at tick 348987
# xBLAST-Premier-Fall-Final-2021-natus-vincere-vs-vitality-m2-nuke.json
# xBLAST-Premier-Fall-Final-2021-natus-vincere-vs-vitality-m3-inferno.json
# xBLAST-Premier-Fall-Final-2021-nip-vs-astralis-m1-nuke.json
# There was a pause called by k0nfig:  logitech 4 life at tick 206635
# xBLAST-Premier-Fall-Final-2021-nip-vs-astralis-m2-overpass.json
# There was a pause called by hampus:  .tech at tick 436171
# There was a pause called by hampus:  .tech at tick 446528
# There was a pause called by hampus:  .tech at tick 446709
# There was a pause called by hampus:  .tech at tick 446852
# There was a pause called by hampus:  .tech at tick 447010
# There was a pause called by hampus:  !pause at tick 447357
# There was a pause called by device:  da vi skrev tech at tick 458928
# There was a pause called by k0nfig:  .pause at tick 459489
# There was a pause called by k0nfig:  !pause at tick 459661
# There was a pause called by hampus:  we cant pause mid round? at tick 462789
# There was a pause called by device:  dno vi skrev tech og så körte vi bare videre fordi ingen sagde noget at tick 464318
# xBLAST-Premier-Fall-Final-2021-vitality-vs-astralis-m1-nuke.json
# xBLAST-Premier-Fall-Final-2021-vitality-vs-astralis-m2-dust2.json
# xBLAST-Premier-Fall-Final-2021-vitality-vs-astralis-m2-inferno.json
# xBLAST-Premier-Fall-Final-2021-vitality-vs-astralis-m3-inferno.json
# There was a pause called by apEX:  !tech at tick 17824
# There was a pause called by apEX:  .tech at tick 18007
# There was a pause called by apEX:  !pause at tick 18249
# There was a pause called by apEX:  .pause at tick 18432
# There was a pause called by Xyp9x:  its paused at tick 18850
# xBLAST-Premier-Fall-Final-2021-vitality-vs-astralis-m3-mirage.json
# There was a pause called by Xyp9x:  .tech at tick 22668
# There was a pause called by Xyp9x:  .pause at tick 22851
# There was a pause called by gla1ve:  .tech at tick 22888
# There was a pause called by apEX:  !pause at tick 23154
# xBLAST-Premier-Fall-Final-2021-vitality-vs-liquid-m1-mirage.json
# There was a pause called by shox :  .tech at tick 12060
# There was a pause called by shox :  .pause at tick 12400
# There was a pause called by ZywOo:  .pause at tick 12426
# There was a pause called by shox :  !tech at tick 12564
# There was a pause called by Stewie2K:  !pause at tick 12689
# There was a pause called by ZywOo:  !unpause  at tick 21644
# There was a pause called by ZywOo:  !pause at tick 22063
# There was a pause called by Stewie2K:  !pause at tick 22543
# There was a pause called by apEX:  need tech and mic at the same time at tick 98056
# There was a pause called by apEX:  !tech at tick 98310
# There was a pause called by apEX:  .pause at tick 98819
# There was a pause called by ZywOo:  !pause at tick 98836
# There was a pause called by apEX:  !pause at tick 100724
# There was a pause called by apEX:  !pause at tick 102891
# There was a pause called by Stewie2K:  !pause at tick 102949
# There was a pause called by ZywOo:  they gonna pause for us  at tick 107715
# There was a pause called by shox :  apprently they have to make the pause at tick 107930
# There was a pause called by Stewie2K:  k so i unpause? at tick 108184
# There was a pause called by shox :  but when we unpause it doesnt happens at tick 109273
# There was a pause called by shox :  so we pause again xd at tick 109631
# There was a pause called by Stewie2K:  should i unpause now? at tick 110271
# There was a pause called by Stewie2K:  !pause at tick 110797
# xBLAST-Premier-Fall-Final-2021-vitality-vs-liquid-m2-dust2.json
# xBLAST-Premier-Fall-Final-2022-faze-vs-heroic-m1-ancient.json
# There was a pause called by karrigan:  .tech at tick 274298
# There was a pause called by karrigan:  !tech at tick 274602
# There was a pause called by karrigan:  pause at tick 274809
# xBLAST-Premier-Fall-Final-2022-faze-vs-heroic-m2-inferno.json
# xBLAST-Premier-Fall-Final-2022-faze-vs-ninjas-in-pyjamas-m1-overpass.json
# xBLAST-Premier-Fall-Final-2022-faze-vs-ninjas-in-pyjamas-m2-nuke.json
# There was a pause called by ropz:  !pause at tick 259507
# There was a pause called by karrigan:  .tech at tick 259829
# xBLAST-Premier-Fall-Final-2022-faze-vs-ninjas-in-pyjamas-m3-mirage.json
# xBLAST-Premier-Fall-Final-2022-faze-vs-og-m1-ancient.json
# There was a pause called by nexa:  .tech at tick 37316
# There was a pause called by nexa:  .pause at tick 38040
# There was a pause called by nexa:  .tech at tick 38407
# There was a pause called by flameZ:  !tech at tick 38420
# There was a pause called by degster:  .tech at tick 38746
# There was a pause called by flameZ:  !pause at tick 38791
# There was a pause called by NEOFRAG:  !tech at tick 355951
# There was a pause called by nexa:  .tech at tick 356051
# There was a pause called by NEOFRAG:  .tech at tick 356121
# There was a pause called by karrigan:  .pause at tick 356270
# xBLAST-Premier-Fall-Final-2022-faze-vs-og-m2-mirage.json
# xBLAST-Premier-Fall-Final-2022-heroic-vs-faze-m1-overpass.json
# There was a pause called by karrigan:  .tech at tick 202001
# There was a pause called by ropz:  !pause at tick 202257
# xBLAST-Premier-Fall-Final-2022-heroic-vs-faze-m2-inferno.json
# There was a pause called by karrigan:  .tech at tick 321656
# There was a pause called by ropz:  !pause at tick 321727
# xBLAST-Premier-Fall-Final-2022-heroic-vs-faze-m3-mirage.json
# xBLAST-Premier-Fall-Final-2022-heroic-vs-g2-m1-mirage.json
# xBLAST-Premier-Fall-Final-2022-heroic-vs-g2-m2-nuke.json
# There was a pause called by sjuush:  !pause at tick 365389
# xBLAST-Premier-Fall-Final-2022-heroic-vs-g2-m3-vertigo.json
# There was a pause called by HooXi:  !pause at tick 341021
# xBLAST-Premier-Fall-Final-2022-heroic-vs-ninjas-in-pyjamas-m1-inferno.json
# There was a pause called by REZ:  .tech at tick 19643
# xBLAST-Premier-Fall-Final-2022-heroic-vs-ninjas-in-pyjamas-m2-ancient.json
# xBLAST-Premier-Fall-Final-2022-heroic-vs-ninjas-in-pyjamas-m3-overpass.json
# xBLAST-Premier-Fall-Final-2022-liquid-vs-g2-m1-vertigo.json
# There was a pause called by YEKINDAR:  .tech at tick 67067
# There was a pause called by EliGE:  .tech at tick 67069
# There was a pause called by EliGE:  !pause at tick 67349
# There was a pause called by HooXi:  .tech at tick 156620
# There was a pause called by HooXi:  !pause at tick 156988
# xBLAST-Premier-Fall-Final-2022-liquid-vs-g2-m2-mirage.json
# There was a pause called by NiKo :  .tech at tick 290213
# There was a pause called by HooXi:  !pause at tick 290352
# There was a pause called by NiKo :  !pause at tick 290397
# xBLAST-Premier-Fall-Final-2022-liquid-vs-heroic-m1-overpass.json
# There was a pause called by nitr0:  !pause at tick 29800
# xBLAST-Premier-Fall-Final-2022-liquid-vs-heroic-m2-inferno.json
# There was a pause called by cadiaN:  .tech at tick 39048
# There was a pause called by sjuush:  !pause at tick 39103
# xBLAST-Premier-Fall-Final-2022-liquid-vs-heroic-m3-vertigo.json
# xBLAST-Premier-Fall-Final-2022-natus-vincere-vs-liquid-m1-inferno.json
# There was a pause called by Perfecto:  tech at tick 365126
# There was a pause called by sdy:  .tech at tick 365301
# There was a pause called by electronic:  .tech at tick 365316
# There was a pause called by NAF-FLY:  !pause at tick 365484
# There was a pause called by EliGE:  !pause at tick 365494
# There was a pause called by nitr0:  .tech at tick 365521
# There was a pause called by EliGE:  !pause at tick 368207
# There was a pause called by EliGE:  !pause at tick 435345
# There was a pause called by YEKINDAR:  .tech at tick 435360
# There was a pause called by Perfecto:  !pause at tick 435484
# There was a pause called by s1mple:  !pause at tick 436847
# There was a pause called by EliGE:  !pause at tick 436969
# xBLAST-Premier-Fall-Final-2022-natus-vincere-vs-liquid-m2-dust2.json
# xBLAST-Premier-Fall-Final-2022-natus-vincere-vs-liquid-m3-mirage.json
# xBLAST-Premier-Fall-Final-2022-ninjas-in-pyjamas-vs-natus-vincere-m1-inferno.json
# There was a pause called by REZ:  .tech at tick 55459
# There was a pause called by hampus:  .tech at tick 55465
# There was a pause called by es3tag:  .tech at tick 55497
# There was a pause called by es3tag:  .pause at tick 55735
# There was a pause called by hampus:  !tech at tick 55789
# There was a pause called by REZ:  !pause at tick 56142
# There was a pause called by sdy:  Logitech, the best way to game(not sposnored) at tick 535083
# xBLAST-Premier-Fall-Final-2022-ninjas-in-pyjamas-vs-natus-vincere-m2-mirage.json
# There was a pause called by electronic:  !pause at tick 11846
# xBLAST-Premier-Fall-Final-2022-ninjas-in-pyjamas-vs-natus-vincere-m3-overpass.json
# There was a pause called by Perfecto:  !pause at tick 24094
# xBLAST-Premier-Fall-Final-2022-og-vs-ninjas-in-pyjamas-m1-ancient.json
# There was a pause called by es3tag:  .tech at tick 303113
# There was a pause called by Brollan:  tech at tick 303245
# There was a pause called by es3tag:  .tech at tick 448544
# There was a pause called by F1KU:  !pause at tick 454114
# xBLAST-Premier-Fall-Final-2022-og-vs-ninjas-in-pyjamas-m2-vertigo.json
# xBLAST-Premier-Fall-Groups-2021-astralis-vs-liquid-m1-vertigo.json
# xBLAST-Premier-Fall-Groups-2021-astralis-vs-liquid-m2-nuke.json
# There was a pause called by Xyp9x:  .tech at tick 30286
# There was a pause called by Xyp9x:  !tech at tick 30905
# There was a pause called by Bubzkji:  !pause at tick 31061
# There was a pause called by Xyp9x:  !pause at tick 38106
# There was a pause called by Stewie2K:  .tech at tick 386523
# There was a pause called by Grim:  !pause at tick 386561
# There was a pause called by EliGE:  !pause at tick 390715
# xBLAST-Premier-Fall-Groups-2021-astralis-vs-liquid-m3-dust2.json
# xBLAST-Premier-Fall-Groups-2021-astralis-vs-vitality-m1-overpass.json
# xBLAST-Premier-Fall-Groups-2021-astralis-vs-vitality-m2-nuke.json
# xBLAST-Premier-Fall-Groups-2021-complexity-vs-faze-m1-dust2.json
# There was a pause called by es3tag:  !pause at tick 31763
# There was a pause called by jks:  pausemaker  at tick 32361
# There was a pause called by es3tag:  !unpause at tick 33096
# There was a pause called by es3tag:  !pause at tick 33248
# There was a pause called by jks:  pausemaker crashed at tick 332810
# There was a pause called by Twistzz:  fucking pausemaker at tick 334170
# xBLAST-Premier-Fall-Groups-2021-complexity-vs-faze-m2-nuke.json
# There was a pause called by es3tag:  !tech at tick 2175
# There was a pause called by es3tag:  !pause at tick 2339
# There was a pause called by es3tag:  .pause at tick 2612
# There was a pause called by karrigan:  !tech at tick 297976
# There was a pause called by karrigan:  .tech at tick 298205
# There was a pause called by blameF:  pause at tick 298517
# There was a pause called by poizon:   ! pause at tick 298873
# There was a pause called by rain :  !pause at tick 306323
# xBLAST-Premier-Fall-Groups-2021-complexity-vs-faze-m3-ancient.json
# xBLAST-Premier-Fall-Groups-2021-faze-vs-complexity-m1-nuke.json
# There was a pause called by blameF:  !tech at tick 115388
# There was a pause called by blameF:  .tech at tick 115584
# There was a pause called by blameF:  .pause at tick 115817
# There was a pause called by blameF:  !pause at tick 116019
# xBLAST-Premier-Fall-Groups-2021-faze-vs-complexity-m2-ancient.json
# xBLAST-Premier-Fall-Groups-2021-g2-vs-big-m1-dust2.json
# xBLAST-Premier-Fall-Groups-2021-g2-vs-big-m2-inferno.json
# xBLAST-Premier-Fall-Groups-2021-g2-vs-nip-m1-ancient.json
# xBLAST-Premier-Fall-Groups-2021-g2-vs-nip-m2-mirage.json
# xBLAST-Premier-Fall-Groups-2021-g2-vs-nip-m3-inferno.json
# There was a pause called by hampus:  .tech at tick 151718
# There was a pause called by device:  !pause at tick 151726
# There was a pause called by hampus:  .unpause at tick 155951
# There was a pause called by hampus:  .pause at tick 156118
# There was a pause called by device:  !pause at tick 156614
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-complexity-m1-overpass.json
# There was a pause called by electronic:  .tech at tick 142472
# There was a pause called by electronic:  !pause at tick 142817
# There was a pause called by blameF:  .tech at tick 493929
# There was a pause called by jks:  !pause at tick 494230
# There was a pause called by es3tag:  !pause at tick 513427
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-complexity-m2-ancient.json
# There was a pause called by electronic:  !pause at tick 11552
# There was a pause called by electronic:  !pause at tick 15462
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-complexity-m3-nuke.json
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-faze-m1-dust2.json
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-faze-m2-mirage.json
# There was a pause called by s1mple:  tech at tick 23307
# There was a pause called by olofmeister :  !pause at tick 24245
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-og-m1-overpass.json
# There was a pause called by Aleksib:  .tech at tick 320122
# There was a pause called by Aleksib:  !pause at tick 320341
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-og-m2-dust2.json
# There was a pause called by electronic:  .tech at tick 363317
# There was a pause called by Perfecto:  .tech at tick 528316
# There was a pause called by b1t:  .tech at tick 528427
# There was a pause called by Perfecto:  !pause at tick 528504
# There was a pause called by Perfecto:  !unpause at tick 545526
# There was a pause called by flameZ:  type !pause at tick 546127
# There was a pause called by electronic:  !pause at tick 546501
# xBLAST-Premier-Fall-Groups-2021-natus-vincere-vs-og-m3-mirage.json
# xBLAST-Premier-Fall-Groups-2021-nip-vs-big-m1-dust2.json
# xBLAST-Premier-Fall-Groups-2021-nip-vs-big-m2-inferno.json
# xBLAST-Premier-Fall-Groups-2021-nip-vs-big-m2-mirage.json
# xBLAST-Premier-Fall-Groups-2021-nip-vs-big-m3-inferno.json
# xBLAST-Premier-Fall-Groups-2021-og-vs-faze-m1-inferno.json
# xBLAST-Premier-Fall-Groups-2021-og-vs-faze-m2-ancient.json
# xBLAST-Premier-Fall-Groups-2021-og-vs-faze-m3-mirage.json
# There was a pause called by rain :  !pause at tick 129292
# There was a pause called by rain :  !pause at tick 141255
# xBLAST-Premier-Fall-Groups-2021-vitality-vs-astralis-m1-nuke.json
# xBLAST-Premier-Fall-Groups-2021-vitality-vs-astralis-m2-vertigo.json
# There was a pause called by Bubzkji:  .unpause at tick 203665
# There was a pause called by Xyp9x:  !pause at tick 203901
# There was a pause called by Lucky:  .unpause at tick 458913
# xBLAST-Premier-Fall-Groups-2021-vitality-vs-astralis-m3-dust2.json
# xBLAST-Premier-Fall-Groups-2021-vitality-vs-liquid-m1-inferno.json
# xBLAST-Premier-Fall-Groups-2021-vitality-vs-liquid-m2-vertigo.json
# xBLAST-Premier-Fall-Groups-2021-vitality-vs-liquid-m3-mirage.json
# There was a pause called by apEX:  .tech at tick 413327
# xBLAST-Premier-Fall-Groups-2022-astralis-vs-og-m1-ancient.json
# There was a pause called by F1KU:  .tech at tick 157583
# There was a pause called by flameZ:  .pause at tick 157749
# There was a pause called by flameZ:  !pause at tick 157936
# xBLAST-Premier-Fall-Groups-2022-astralis-vs-og-m2-mirage.json
# xBLAST-Premier-Fall-Groups-2022-faze-vs-astralis-m1-inferno.json
# There was a pause called by gla1ve:  .tech at tick 10008
# There was a pause called by gla1ve:  .pause at tick 10200
# There was a pause called by Xyp9x:  !pause at tick 10362
# There was a pause called by k0nfig:  !unpause at tick 12380
# xBLAST-Premier-Fall-Groups-2022-faze-vs-astralis-m2-ancient.json
# There was a pause called by k0nfig:  .pause at tick 116817
# There was a pause called by Xyp9x:  !pause at tick 116937
# There was a pause called by gla1ve:  .tech at tick 116943
# There was a pause called by k0nfig:  tech at tick 117141
# xBLAST-Premier-Fall-Groups-2022-faze-vs-astralis-m3-nuke.json
# There was a pause called by blameF:  .pause at tick 39725
# There was a pause called by blameF:  !pause at tick 39963
# xBLAST-Premier-Fall-Groups-2022-faze-vs-heroic-inferno.json
# xBLAST-Premier-Fall-Groups-2022-faze-vs-heroic-nuke.json
# There was a pause called by ropz:  !pause at tick 71676
# xBLAST-Premier-Fall-Groups-2022-faze-vs-og-m1-ancient.json
# xBLAST-Premier-Fall-Groups-2022-faze-vs-og-m2-mirage.json
# xBLAST-Premier-Fall-Groups-2022-faze-vs-og-m3-inferno.json
# xBLAST-Premier-Fall-Groups-2022-g2-vs-big-m1-vertigo.json
# There was a pause called by huNter:  !pause at tick 60252
# xBLAST-Premier-Fall-Groups-2022-g2-vs-big-m2-dust2.json
# There was a pause called by HooXi:  !pause at tick 66717
# xBLAST-Premier-Fall-Groups-2022-g2-vs-liquid-mirage.json
# xBLAST-Premier-Fall-Groups-2022-g2-vs-vitality-m1-vertigo.json
# xBLAST-Premier-Fall-Groups-2022-g2-vs-vitality-m2-dust2.json
# xBLAST-Premier-Fall-Groups-2022-g2-vs-vitality-m3-mirage.json
# xBLAST-Premier-Fall-Groups-2022-heroic-vs-big-nuke.json
# There was a pause called by Krimbo:  !pause at tick 252384
# There was a pause called by syrsoN:  !unpause at tick 253971
# There was a pause called by Krimbo:  !pause at tick 254268
# xBLAST-Premier-Fall-Groups-2022-heroic-vs-liquid-m1-vertigo.json
# There was a pause called by nitr0:  !pause at tick 46569
# There was a pause called by stavn:  !pause at tick 163952
# xBLAST-Premier-Fall-Groups-2022-heroic-vs-liquid-m2-overpass.json
# xBLAST-Premier-Fall-Groups-2022-liquid-vs-natus-vincere-dust2.json
# xBLAST-Premier-Fall-Groups-2022-liquid-vs-ninjas-in-pyjamas-m1-overpass-p1.json
# There was a pause called by EliGE:  .tech at tick 66528
# There was a pause called by nitr0:  !pause at tick 66609
# There was a pause called by EliGE:  .unpause at tick 67170
# There was a pause called by nitr0:  !pause at tick 67208
# xBLAST-Premier-Fall-Groups-2022-liquid-vs-ninjas-in-pyjamas-m1-overpass-p2.json
# xBLAST-Premier-Fall-Groups-2022-liquid-vs-ninjas-in-pyjamas-m2-mirage.json
# There was a pause called by nitr0:  !pause at tick 445279
# There was a pause called by EliGE:  !pause at tick 447290
# xBLAST-Premier-Fall-Groups-2022-natus-vincere-vs-g2-mirage.json
# xBLAST-Premier-Fall-Groups-2022-natus-vincere-vs-vitality-m1-inferno.json
# xBLAST-Premier-Fall-Groups-2022-natus-vincere-vs-vitality-m2-mirage.json
# xBLAST-Premier-Fall-Groups-2022-ninjas-in-pyjamas-vs-astralis-ancient.json
# xBLAST-Premier-Fall-Groups-2022-ninjas-in-pyjamas-vs-astralis-overpass.json
# There was a pause called by blameF:  .tech at tick 75462
# There was a pause called by blameF:  !tech at tick 75948
# There was a pause called by gla1ve:  !pause at tick 75962
# There was a pause called by Xyp9x:  .pause at tick 76006
# There was a pause called by hampus:  !pause at tick 85326
# There was a pause called by Xyp9x:  !pause at tick 143666
# xBLAST-Premier-Fall-Groups-2022-ninjas-in-pyjamas-vs-heroic-m1-inferno.json
# There was a pause called by hampus:  .pause at tick 512052
# There was a pause called by hampus:  .pause at tick 512261
# There was a pause called by hampus:  !pause at tick 512434
# There was a pause called by cadiaN:  not tech at tick 512744
# There was a pause called by hampus:  tech at tick 512989
# xBLAST-Premier-Fall-Groups-2022-ninjas-in-pyjamas-vs-heroic-m2-mirage.json
# There was a pause called by cadiaN:  .pause at tick 342759
# There was a pause called by stavn:  !pause at tick 343736
# xBLAST-Premier-Fall-Groups-2022-ninjas-in-pyjamas-vs-heroic-m3-overpass.json
# xBLAST-Premier-Fall-Groups-2022-og-vs-astralis-mirage.json
# xBLAST-Premier-Fall-Groups-2022-vitality-vs-astralis-mirage.json
# xBLAST-Premier-Fall-Groups-2022-vitality-vs-g2-m1-vertigo.json
# xBLAST-Premier-Fall-Groups-2022-vitality-vs-g2-m2-nuke.json
# xBLAST-Premier-Fall-Groups-2022-vitality-vs-g2-m3-inferno.json
# xBLAST-Premier-Fall-Groups-2022-vitality-vs-ninjas-in-pyjames-inferno.json
# There was a pause called by Magisk:  .pause at tick 472109
# xBLAST-Premier-Fall-Groups-2022-vitality-vs-og-dust2.json
# xBLAST-Premier-Fall-Series-2020-30oct-vitality-vs-big-m1-dust2.json
# xBLAST-Premier-Fall-Series-2020-30oct-vitality-vs-big-m2-overpass.json
# xBLAST-Premier-Fall-Series-2020-31oct-vitality-vs-big-m1-dust2.json
# xBLAST-Premier-Fall-Series-2020-31oct-vitality-vs-big-m2-nuke.json
# xBLAST-Premier-Fall-Series-2020-31oct-vitality-vs-big-m3-inferno.json
# There was a pause called by tabseN:  !tech at tick 216533
# There was a pause called by tabseN:  !pause at tick 216790
# There was a pause called by tabseN:  !pause at tick 220973
# xBLAST-Premier-Fall-Series-2020-big-vs-faze-m1-mirage.json
# There was a pause called by syrsoN:  .tech at tick 33497
# There was a pause called by tabseN:  !pause at tick 33524
# There was a pause called by syrsoN:  !pause at tick 33802
# There was a pause called by tabseN:  !tech at tick 33903
# There was a pause called by syrsoN:  .tech at tick 33906
# There was a pause called by syrsoN:  .pause at tick 43525
# There was a pause called by syrsoN:  !pause at tick 43754
# There was a pause called by tiziaN:  !technicaldifficulties at tick 45058
# There was a pause called by syrsoN:  !tech at tick 45112
# There was a pause called by syrsoN:  !pause at tick 48964
# xBLAST-Premier-Fall-Series-2020-big-vs-faze-m2-nuke.json
# xBLAST-Premier-Fall-Series-2020-big-vs-faze-m3-dust2.json
# xBLAST-Premier-Fall-Series-2020-evil-geniuses-vs-og-m1-mirage.json
# There was a pause called by ISSAA:  !unpause at tick 9066
# There was a pause called by NBK-:  .tech at tick 402907
# There was a pause called by NBK-:  .pause at tick 403057
# There was a pause called by Aleksib:  !pause at tick 403069
# There was a pause called by ISSAA:  !unpause at tick 404146
# There was a pause called by Aleksib:  !unpause at tick 404803
# There was a pause called by ISSAA:  !pause at tick 404980
# xBLAST-Premier-Fall-Series-2020-evil-geniuses-vs-og-m2-inferno.json
# There was a pause called by tarik:  !tech at tick 204814
# There was a pause called by tarik:  .tech at tick 205093
# There was a pause called by CeRq:  !pause at tick 205105
# There was a pause called by CeRq:  !pause at tick 209606
# There was a pause called by NBK-:  !pause at tick 254197
# There was a pause called by stanislaw:  !pause at tick 258818
# There was a pause called by NBK-:  !unpause at tick 259263
# There was a pause called by tarik:  do !pause at tick 259536
# There was a pause called by CeRq:  pause again at tick 259772
# There was a pause called by tarik:  !pause at tick 380040
# There was a pause called by tarik:  !pause at tick 380560
# There was a pause called by tarik:  tech for us after at tick 455673
# There was a pause called by tarik:  !pause at tick 456208
# There was a pause called by tarik:  !pause at tick 456969
# xBLAST-Premier-Fall-Series-2020-evil-geniuses-vs-og-m3-overpass.json
# There was a pause called by tarik:  !pause at tick 39875
# There was a pause called by Ethan:  !pause at tick 46590
# There was a pause called by NBK-:  !pause at tick 524970
# xBLAST-Premier-Fall-Series-2020-natus-vincere-vs-nip-m1-overpass.json
# There was a pause called by REZ:  !pause at tick 51945
# There was a pause called by hampus:  !pause at tick 63113
# There was a pause called by Boombl4:  !pause at tick 108396
# There was a pause called by electronic:  !pause at tick 108413
# There was a pause called by hampus:  !pause at tick 129314
# There was a pause called by electronic:  !pause at tick 129436
# There was a pause called by REZ:  !pause at tick 277855
# There was a pause called by hampus:  !pause at tick 326080
# xBLAST-Premier-Fall-Series-2020-natus-vincere-vs-nip-m2-nuke.json
# xBLAST-Premier-Fall-Series-2020-natus-vincere-vs-nip-m3-mirage.json
# There was a pause called by Boombl4:  !pause at tick 181462
# There was a pause called by electronic:  !pause at tick 190831
# xBLAST-Premier-Fall-Series-2020-natus-vincere-vs-og-m1-mirage.json
# There was a pause called by electronic:  can we guys use your pause ? at tick 577373
# There was a pause called by ISSAA:  !pause at tick 607820
# There was a pause called by Boombl4:  .tech at tick 623041
# There was a pause called by NBK-:  !pause at tick 623489
# There was a pause called by Boombl4:  !pause at tick 623531
# There was a pause called by NBK-:  !pause at tick 624506
# xBLAST-Premier-Fall-Series-2020-natus-vincere-vs-og-m2-dust2.json
# There was a pause called by ISSAA:  !pause at tick 68098
# There was a pause called by NBK-:  !pause at tick 125174
# There was a pause called by NBK-:  !pause at tick 342862
# There was a pause called by s1mple:  we will give u pause if it keep going at tick 345537
# There was a pause called by NBK-:  !pause at tick 353546
# xBLAST-Premier-Fall-Series-2020-nip-vs-evil-geniuses-m1-overpass.json
# xBLAST-Premier-Fall-Series-2020-nip-vs-evil-geniuses-m2-inferno.json
# There was a pause called by hampus:  but its paused at tick 9318
# There was a pause called by stanislaw:  !pause at tick 312719
# There was a pause called by stanislaw:  tech at tick 312936
# There was a pause called by tarik:  !pause at tick 313952
# There was a pause called by tarik:  !pause at tick 363810
# There was a pause called by twist:  !pause at tick 368318
# There was a pause called by twist:  !pause at tick 369436
# There was a pause called by hampus:  !pause at tick 371293
# There was a pause called by REZ:  !pause at tick 371607
# There was a pause called by hampus:  can u pause at tick 371610
# There was a pause called by tarik:  !pause at tick 371645
# There was a pause called by stanislaw:  !pause at tick 371662
# There was a pause called by CeRq:  !pause at tick 375113
# There was a pause called by stanislaw:  dont unpause at tick 481112
# There was a pause called by stanislaw:  !pause at tick 482035
# There was a pause called by CeRq:  !pause at tick 482118
# There was a pause called by stanislaw:  to pause for mouse dying? at tick 483384
# There was a pause called by hampus:  pause at tick 484892
# There was a pause called by tarik:  !pause at tick 527654
# There was a pause called by CeRq:  !pause at tick 530050
# xBLAST-Premier-Fall-Series-2020-og-vs-natus-vincere-m1-dust2.json
# There was a pause called by Aleksib:  man im begging for no technical issues today at tick 3655
# xBLAST-Premier-Fall-Series-2020-og-vs-natus-vincere-m2-mirage.json
# xBLAST-Premier-Fall-Series-2020-og-vs-natus-vincere-m3-nuke.json
# There was a pause called by Aleksib:  !pause at tick 107807
# There was a pause called by ISSAA:  !pause at tick 109145
# There was a pause called by NBK-:  !pause at tick 160940
# There was a pause called by NBK-:  !pause at tick 165465
# There was a pause called by NBK-:  !pause at tick 228838
# There was a pause called by NBK-:  !pause at tick 244023
# There was a pause called by NBK-:  !pause at tick 276141
# There was a pause called by NBK-:  !pause at tick 318399
# There was a pause called by NBK-:  unpause admin at tick 392125
# There was a pause called by s1mple:  !pause at tick 392966
# xBLAST-Premier-Fall-Showdown-2021-heroic-vs-og-m1-inferno.json
# xBLAST-Premier-Fall-Showdown-2021-heroic-vs-og-m2-overpass.json
# xBLAST-Premier-Fall-Showdown-2021-virtus-pro-vs-liquid-m1-inferno.json
# xBLAST-Premier-Fall-Showdown-2021-virtus-pro-vs-liquid-m2-vertigo.json
# There was a pause called by YEKINDAR:  .tech at tick 205706
# There was a pause called by SANJI:  .pause at tick 206333
# There was a pause called by YEKINDAR:  .tech  at tick 206553
# There was a pause called by SANJI:  !pause at tick 206580
# There was a pause called by EliGE:  .unpause at tick 221604
# xBLAST-Premier-Fall-Showdown-2021-virtus-pro-vs-liquid-m3-overpass.json
# xBLAST-Premier-Fall-Showdown-2021-virtus-pro-vs-movistar-riders-m1-vertigo.json
# There was a pause called by mopoz:  .tech at tick 381926
# There was a pause called by mopoz:  !pause at tick 382185
# xBLAST-Premier-Fall-Showdown-2021-virtus-pro-vs-movistar-riders-m2-mirage.json
# xBLAST-Premier-Fall-Showdown-2022-Europe-astralis-vs-eternal-fire-m1-dust2.json
# There was a pause called by imoRR:  .tech at tick 514692
# There was a pause called by xfl0ud:  !tech at tick 515363
# There was a pause called by imoRR:  !pause at tick 515397
# There was a pause called by blameF:  !pause at tick 515533
# xBLAST-Premier-Fall-Showdown-2022-Europe-astralis-vs-eternal-fire-m2-overpass.json
# xBLAST-Premier-Fall-Showdown-2022-Europe-astralis-vs-eternal-fire-m3-nuke.json
# xBLAST-Premier-Fall-Showdown-2022-Europe-astralis-vs-heroic-m1-ancient.json
# xBLAST-Premier-Fall-Showdown-2022-Europe-astralis-vs-heroic-m2-nuke.json
# There was a pause called by Xyp9x:  .tech at tick 133291
# There was a pause called by Xyp9x:  .pause at tick 133469
# There was a pause called by TeSeS:  !pause at tick 142272
# There was a pause called by TeSeS:  !pause at tick 144175
# xBLAST-Premier-Fall-Showdown-2022-Europe-vitality-vs-astralis-m1-nuke.json
# xBLAST-Premier-Fall-Showdown-2022-Europe-vitality-vs-astralis-m2-dust2.json
# xBLAST-Premier-Fall-Showdown-2022-Europe-vitality-vs-astralis-m3-inferno.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-evil-geniuses-m1-inferno.json
# There was a pause called by tarik:  tech at tick 108602
# There was a pause called by stanislaw:  .tech at tick 108680
# There was a pause called by CeRq:  !pause at tick 108998
# There was a pause called by stanislaw:  !pause at tick 108999
# There was a pause called by device:  !pause then at tick 126076
# There was a pause called by tarik:  !pause at tick 126359
# There was a pause called by CeRq:  !pause at tick 126558
# There was a pause called by device:  !pause at tick 256897
# xBLAST-Premier-Global-Final-2020-astralis-vs-evil-geniuses-m2-overpass.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-evil-geniuses-m3-vertigo.json
# There was a pause called by device:  !pause at tick 323078
# xBLAST-Premier-Global-Final-2020-astralis-vs-g2-m1-dust2.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-g2-m2-vertigo.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-g2-m3-inferno.json
# There was a pause called by AmaNEk:  !pause at tick 355596
# xBLAST-Premier-Global-Final-2020-astralis-vs-natus-vincere-m1-nuke.json
# There was a pause called by s1mple:  !pause at tick 153308
# xBLAST-Premier-Global-Final-2020-astralis-vs-natus-vincere-m2-inferno.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-vitality-m1-dust2.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-vitality-m2-overpass.json
# xBLAST-Premier-Global-Final-2020-astralis-vs-vitality-m3-inferno.json
# There was a pause called by device:  !pause at tick 1902
# There was a pause called by gla1ve:  !pause at tick 2021
# xBLAST-Premier-Global-Final-2020-complexity-vs-natus-vincere-m1-mirage.json
# xBLAST-Premier-Global-Final-2020-complexity-vs-natus-vincere-m2-nuke.json
# There was a pause called by electronic:  .tech at tick 20370
# There was a pause called by electronic:  !pause at tick 20822
# There was a pause called by Boombl4:  !pause at tick 28700
# xBLAST-Premier-Global-Final-2020-complexity-vs-natus-vincere-m3-inferno.json
# There was a pause called by k0nfig :  !pause at tick 384192
# xBLAST-Premier-Global-Final-2020-evil-geniuses-vs-furia-m1-inferno.json
# There was a pause called by stanislaw:  !pause at tick 53749
# There was a pause called by stanislaw:  !pause at tick 54935
# There was a pause called by CeRq:  !pause at tick 54939
# xBLAST-Premier-Global-Final-2020-evil-geniuses-vs-furia-m2-mirage.json
# There was a pause called by arT:  !pause at tick 21099
# xBLAST-Premier-Global-Final-2020-evil-geniuses-vs-furia-m3-nuke.json
# There was a pause called by tarik:  !pause at tick 89430
# There was a pause called by stanislaw:  !pause at tick 97390
# xBLAST-Premier-Global-Final-2020-evil-geniuses-vs-liquid-m1-inferno.json
# There was a pause called by stanislaw:  !pause at tick 258351
# There was a pause called by Stewie2K:  !pause at tick 280898
# There was a pause called by Stewie2K:  no talking during pause pls at tick 432090
# xBLAST-Premier-Global-Final-2020-evil-geniuses-vs-liquid-m2-dust2.json
# xBLAST-Premier-Global-Final-2020-g2-vs-furia-m1-inferno.json
# There was a pause called by KSCERATO:  .tech at tick 103747
# There was a pause called by arT:  .tech at tick 103776
# There was a pause called by arT:  .pause at tick 104008
# There was a pause called by arT:  !pause at tick 104148
# There was a pause called by arT:  !pause at tick 110532
# There was a pause called by NiKo :  !pause at tick 133589
# There was a pause called by arT:  !pause at tick 378449
# There was a pause called by arT:  .unpause at tick 378826
# There was a pause called by arT:  it unpaused by mistake at tick 407027
# There was a pause called by arT:  !pause at tick 506075
# There was a pause called by arT:  !pause at tick 513270
# xBLAST-Premier-Global-Final-2020-g2-vs-furia-m2-mirage.json
# xBLAST-Premier-Global-Final-2020-g2-vs-furia-m3-nuke.json
# xBLAST-Premier-Global-Final-2020-liquid-vs-natus-vincere-m1-inferno.json
# There was a pause called by Boombl4:  .tech at tick 317156
# There was a pause called by Boombl4:  !pause at tick 317450
# There was a pause called by EliGE:  !pause at tick 317512
# There was a pause called by Perfecto:  !pause at tick 325093
# xBLAST-Premier-Global-Final-2020-liquid-vs-natus-vincere-m2-nuke.json
# xBLAST-Premier-Global-Final-2020-natus-vincere-vs-g2-m1-train.json
# xBLAST-Premier-Global-Final-2020-natus-vincere-vs-g2-m2-mirage.json
# xBLAST-Premier-Global-Final-2020-natus-vincere-vs-liquid-m1-inferno.json
# xBLAST-Premier-Global-Final-2020-natus-vincere-vs-liquid-m2-nuke.json
# xBLAST-Premier-Global-Final-2020-vitality-vs-complexity-m1-mirage.json
# xBLAST-Premier-Global-Final-2020-vitality-vs-complexity-m2-dust2.json
# xBLAST-Premier-Global-Final-2020-vitality-vs-liquid-m1-nuke.json
# xBLAST-Premier-Global-Final-2020-vitality-vs-liquid-m2-vertigo.json
# xBLAST-Premier-Global-Final-2020-vitality-vs-natus-vincere-m1-nuke.json
# There was a pause called by Boombl4:  !pause at tick 538886
# There was a pause called by electronic:  !pause at tick 551794
# xBLAST-Premier-Global-Final-2020-vitality-vs-natus-vincere-m2-overpass.json
# There was a pause called by Boombl4:  !pause at tick 476521
# xBLAST-Premier-Global-Final-2020-vitality-vs-natus-vincere-m3-dust2.json
# xBLAST-Premier-Spring-2020-Americas-Finals-furia-vs-liquid-m1-vertigo.json
# xBLAST-Premier-Spring-2020-Americas-Finals-furia-vs-liquid-m2-nuke.json
# There was a pause called by arT:  !pause at tick 280194
# There was a pause called by arT:  .unpause at tick 282738
# There was a pause called by Stewie2K:  !pause at tick 283598
# There was a pause called by VINI:  !pause at tick 305809
# There was a pause called by VINI:  !pause at tick 306313
# There was a pause called by arT:  !pause at tick 307092
# There was a pause called by NAF:  !pause at tick 307266
# There was a pause called by arT:  !pause at tick 426158
# There was a pause called by arT:  !pause at tick 432591
# There was a pause called by arT:  !pause at tick 448306
# There was a pause called by arT:  !pause at tick 450761
# There was a pause called by arT:  !pause at tick 472987
# There was a pause called by arT:  !pause at tick 474246
# xBLAST-Premier-Spring-2020-Americas-Finals-furia-vs-liquid-m3-mirage.json
# There was a pause called by arT:  !pause at tick 122732
# There was a pause called by arT:  !pause at tick 168773
# There was a pause called by arT:  !pause at tick 186748
# There was a pause called by VINI:  !pause at tick 186867
# There was a pause called by arT:  !pause at tick 188807
# There was a pause called by arT:  !pause at tick 286370
# There was a pause called by arT:  !pause at tick 296966
# There was a pause called by arT:  !pause at tick 321089
# There was a pause called by arT:  !pause at tick 325085
# There was a pause called by arT:  !pause at tick 357263
# There was a pause called by arT:  !pause at tick 360169
# There was a pause called by arT:  !pause at tick 368030
# There was a pause called by arT:  !pause at tick 372699
# xBLAST-Premier-Spring-2020-Europe-Finals-faze-vs-vitality-m1-nuke.json
# xBLAST-Premier-Spring-2020-Europe-Finals-faze-vs-vitality-m2-dust2.json
# xBLAST-Premier-Spring-2020-Europe-Finals-g2-vs-natus-vincere-m1-mirage.json
# xBLAST-Premier-Spring-2020-Europe-Finals-g2-vs-natus-vincere-m2-train.json
# xBLAST-Premier-Spring-2020-Europe-Finals-g2-vs-natus-vincere-m3-nuke.json
# There was a pause called by Boombl4:  .tech at tick 16683
# There was a pause called by Boombl4:  pause at tick 17302
# There was a pause called by Boombl4:  !pause at tick 17538
# There was a pause called by s1mple:  !pause at tick 17549
# There was a pause called by electronic:  !pause at tick 21735
# xBLAST-Premier-Spring-2020-Europe-Finals-g2-vs-vitality-m1-inferno.json
# xBLAST-Premier-Spring-2020-Europe-Finals-g2-vs-vitality-m2-mirage.json
# There was a pause called by kennyS:  no pause during timeout at tick 550308
# xBLAST-Premier-Spring-2020-Europe-Finals-natus-vincere-vs-vitality-m1-inferno.json
# There was a pause called by apEX:  .tech at tick 11493
# There was a pause called by apEX:  !pause at tick 11866
# There was a pause called by apEX:  !pause at tick 26046
# There was a pause called by apEX:  !pause at tick 321051
# There was a pause called by apEX:  !pause at tick 324873
# xBLAST-Premier-Spring-2020-Europe-Finals-natus-vincere-vs-vitality-m2-overpass.json
# xBLAST-Premier-Spring-2020-Europe-Finals-natus-vincere-vs-vitality-m3-nuke.json
# There was a pause called by electronic:  .tech at tick 397246
# xBLAST-Premier-Spring-2020-Europe-Finals-vitality-vs-faze-m1-nuke.json
# xBLAST-Premier-Spring-2020-Europe-Finals-vitality-vs-faze-m2-dust2.json
# There was a pause called by apEX:  !tech at tick 341901
# There was a pause called by apEX:  .tech at tick 342199
# There was a pause called by ZywOo:  .pause at tick 342500
# There was a pause called by apEX:  !pause at tick 342691
# There was a pause called by shox :  !pause at tick 347748
# xBLAST-Premier-Spring-2020-Europe-Showdown-astralis-vs-vitality-nuke.json
# xBLAST-Premier-Spring-2020-Europe-Showdown-fnatic-vs-mousesports-train.json
# xBLAST-Premier-Spring-2020-Europe-Showdown-fnatic-vs-vitality-m1-nuke.json
# xBLAST-Premier-Spring-2020-Europe-Showdown-fnatic-vs-vitality-m2-inferno.json
# xBLAST-Premier-Spring-2020-Europe-Showdown-mousesports-vs-astralis-m1-overpass.json
# There was a pause called by karrigan:  !pause at tick 69779
# There was a pause called by karrigan:  !unpause at tick 73779
# There was a pause called by device:  !pause at tick 74072
# There was a pause called by karrigan:  !pause at tick 74218
# There was a pause called by Snappi:  !pause at tick 354198
# There was a pause called by Snappi:  tech at tick 354533
# There was a pause called by ropz:  !pause at tick 355780
# There was a pause called by device:  !pause at tick 356442
# xBLAST-Premier-Spring-2020-Europe-Showdown-mousesports-vs-astralis-m2-train.json
# xBLAST-Premier-Spring-Final-2021-big-vs-natus-vincere-m1-dust2.json
# xBLAST-Premier-Spring-Final-2021-big-vs-natus-vincere-m2-inferno.json
# xBLAST-Premier-Spring-Final-2021-g2-vs-big-m1-dust2.json
# There was a pause called by syrsoN:  .tech at tick 389916
# There was a pause called by huNter-:  !pause at tick 390715
# There was a pause called by NiKo :  !pause at tick 390772
# xBLAST-Premier-Spring-Final-2021-g2-vs-big-m2-mirage.json
# There was a pause called by NiKo :  !pause at tick 18572
# There was a pause called by NiKo :  !pause at tick 20463
# There was a pause called by syrsoN:  !pause at tick 67014
# xBLAST-Premier-Spring-Final-2021-g2-vs-big-m3-vertigo.json
# There was a pause called by nexa:  .tech at tick 81050
# There was a pause called by huNter-:  !pause at tick 81051
# There was a pause called by NiKo :  !pause at tick 84624
# There was a pause called by tabseN:  .tech at tick 323392
# There was a pause called by tabseN:  !pause at tick 323562
# There was a pause called by tabseN:  !pause at tick 325479
# xBLAST-Premier-Spring-Final-2021-g2-vs-complexity-m1-vertigo.json
# xBLAST-Premier-Spring-Final-2021-g2-vs-complexity-m2-nuke.json
# There was a pause called by nexa:  !pause at tick 243738
# There was a pause called by nexa:  !pause at tick 247853
# xBLAST-Premier-Spring-Final-2021-g2-vs-complexity-m3-mirage.json
# There was a pause called by NiKo :  .tech at tick 95729
# There was a pause called by NiKo :  !pause at tick 95973
# There was a pause called by NiKo :  !pause at tick 96402
# xBLAST-Premier-Spring-Final-2021-gambit-vs-complexity-m1-mirage.json
# xBLAST-Premier-Spring-Final-2021-gambit-vs-complexity-m2-vertigo.json
# xBLAST-Premier-Spring-Final-2021-jun19-gambit-vs-natus-vincere-m1-dust2.json
# xBLAST-Premier-Spring-Final-2021-jun19-gambit-vs-natus-vincere-m2-ancient.json
# xBLAST-Premier-Spring-Final-2021-jun19-gambit-vs-natus-vincere-m3-mirage.json
# xBLAST-Premier-Spring-Final-2021-jun20-gambit-vs-natus-vincere-m1-dust2.json
# xBLAST-Premier-Spring-Final-2021-jun20-gambit-vs-natus-vincere-m2-mirage.json
# xBLAST-Premier-Spring-Final-2021-natus-vincere-vs-g2-m1-mirage.json
# xBLAST-Premier-Spring-Final-2021-natus-vincere-vs-g2-m2-dust2.json
# xBLAST-Premier-Spring-Final-2021-natus-vincere-vs-g2-m3-nuke.json
# xBLAST-Premier-Spring-Final-2021-nip-vs-big-m1-dust2.json
# There was a pause called by tabseN:  pause at tick 199729
# There was a pause called by syrsoN:  !pause at tick 199800
# xBLAST-Premier-Spring-Final-2021-nip-vs-big-m2-inferno.json
# xBLAST-Premier-Spring-Final-2021-nip-vs-complexity-m1-mirage.json
# xBLAST-Premier-Spring-Final-2021-nip-vs-complexity-m2-ancient.json
# ...
# There was a pause called by TACO:  .unpause at tick 151242
# There was a pause called by azr:  !pause at tick 309466
# There was a pause called by azr:  !pause at tick 332760
# There was a pause called by fallen:  .pause at tick 367393
# xStarSeries-i-League-Season7-renegades-vs-mibr-m3-mirage.json
# There was a pause called by fallen:  .pause at tick 96138
# There was a pause called by fallen:  .pause at tick 128917
# xStarSeries-i-League-Season7-renegades-vs-natus-vincere-m1-inferno.json
# There was a pause called by Zeus:  .pause at tick 102209
# xStarSeries-i-League-Season7-renegades-vs-natus-vincere-m2-mirage.json
# There was a pause called by Zeus:  .pause at tick 56076
# There was a pause called by Zeus:  .pause at tick 99765
# There was a pause called by Zeus:  .pause at tick 333416
# xStarSeries-i-League-Season7-renegades-vs-natus-vincere-m3-train.json
# There was a pause called by Zeus:  .pause at tick 168944
# xStarSeries-i-League-Season7-renegades-vs-nip-m1-mirage.json
# xStarSeries-i-League-Season7-renegades-vs-nip-m2-dust2.json
# There was a pause called by Gratisfaction:  .pause at tick 129774
# There was a pause called by draken:  !unpause at tick 160555
# There was a pause called by jks:  !unpause at tick 160881
# xStarSeries-i-League-Season8-evil-geniuses-vs-fnatic-m1-dust2.json
# xStarSeries-i-League-Season8-evil-geniuses-vs-fnatic-m2-mirage.json
# xStarSeries-i-League-Season8-fnatic-vs-evil-geniuses-m1-mirage.json
# There was a pause called by Ethan:  pause at tick 9611
# There was a pause called by Stanislaw:  .pause at tick 10215
# There was a pause called by Stanislaw:  !unpause at tick 36802
# There was a pause called by JW:  !unpause at tick 38282
# There was a pause called by tarik:  !pause at tick 161920
# There was a pause called by tarik:  !pause at tick 162655
# There was a pause called by KRIMZ:  !pause at tick 163252
# There was a pause called by KRIMZ:  !tech at tick 163676
# xStarSeries-i-League-Season8-fnatic-vs-evil-geniuses-m2-dust2.json
# xStarSeries-i-League-Season8-fnatic-vs-evil-geniuses-m3-inferno.json
# There was a pause called by Stanislaw:  .pause at tick 466355
# There was a pause called by tarik:  !unpause at tick 467540
# There was a pause called by JW:  !unpause at tick 468909
# xStarSeries-i-League-Season8-fnatic-vs-mousesports-m1-train.json
# xStarSeries-i-League-Season8-fnatic-vs-mousesports-m2-inferno.json
# xStarSeries-i-League-Season8-fnatic-vs-renegades-m1-mirage.json
# xStarSeries-i-League-Season8-fnatic-vs-renegades-m2-inferno.json
# xStarSeries-i-League-Season8-renegades-vs-evil-geniuses-m1-inferno.json
# There was a pause called by Stanislaw:  .pause at tick 22782
# There was a pause called by tarik:  !unpause at tick 29142
# There was a pause called by azr:  !unpause at tick 29673
# There was a pause called by Stanislaw:  .pause at tick 182976
# There was a pause called by tarik:  !unpause at tick 185984
# There was a pause called by azr:  !unpause at tick 186506
# xStarSeries-i-League-Season8-renegades-vs-evil-geniuses-m2-mirage.json
# xStarSeries-i-League-Season8-vitality-vs-fnatic-m1-inferno.json
# xStarSeries-i-League-Season8-vitality-vs-fnatic-m2-nuke.json
# xStarSeries-i-League-Season8-vitality-vs-renegades-m1-mirage.json
# xStarSeries-i-League-Season8-vitality-vs-renegades-m2-nuke.json
# xSteelSeries-Invitational-2021-faze-vs-og-m1-cache.json
# xSteelSeries-Invitational-2021-faze-vs-og-m2-cobblestone.json
# xSteelSeries-Nova-Invitational-2022-faze-vs-og-m1-cache.json
# xSteelSeries-Nova-Invitational-2022-faze-vs-og-m2-train.json
# There was a pause called by ropz:  .tech at tick 48875
# There was a pause called by ropz:  .unpause at tick 63867
# There was a pause called by Marix:  .unpause at tick 64076
# There was a pause called by broky:  !pause at tick 167954
# There was a pause called by Twistzz:  .tech at tick 170679
# There was a pause called by Twistzz:  !tech at tick 170951
# There was a pause called by ropz:  .tech at tick 184124
# There was a pause called by Marix:  .unpause at tick 207355
# There was a pause called by rain:  !unpause at tick 208503
# There was a pause called by ropz:  .tech at tick 247836
# There was a pause called by ropz:  .unpause at tick 263014
# There was a pause called by Marix:  .unpause at tick 264247
# There was a pause called by degster:  .upause at tick 264253
# There was a pause called by Twistzz:  .tech at tick 309290
# There was a pause called by Twistzz:  .unpause at tick 333963
# There was a pause called by F1KU:  !unpause at tick 334334
# xSuperNova-CS-GO-Malta-liquid-vs-big-m1-inferno.json
# There was a pause called by EliGE:  !pause at tick 142220
# There was a pause called by EliGE:  tech at tick 142573
# There was a pause called by TACO:  !unpause at tick 150374
# There was a pause called by tabseN:  !unpause at tick 150879
# There was a pause called by nitr0:  !pause at tick 176822
# There was a pause called by tabseN:  !pause at tick 221273
# There was a pause called by tabseN:  !pause at tick 361929
# There was a pause called by smooya:  !pause at tick 476625
# xSuperNova-CS-GO-Malta-liquid-vs-big-m2-overpass.json
# There was a pause called by NAF:  !pause at tick 16055
# There was a pause called by nitr0:  tech at tick 16321
# There was a pause called by TACO:  !unpause at tick 18251
# There was a pause called by EliGE:  !unpause at tick 18302
# There was a pause called by tabseN:  !unpause at tick 18399
# There was a pause called by smooya:  !pause at tick 36396
# There was a pause called by tabseN:  !pause at tick 108415
# There was a pause called by TACO:  !pause at tick 309637
# There was a pause called by tabseN:  !pause at tick 336475
# There was a pause called by nitr0:  !pause at tick 375565
# xSuperNova-CS-GO-Malta-nrg-vs-liquid-m1-overpass.json
# There was a pause called by daps:  .pause at tick 118243
# There was a pause called by daps:  .pause at tick 184246
# There was a pause called by nitr0:  !pause at tick 287243
# There was a pause called by daps:  .pause at tick 309834
# xSuperNova-CS-GO-Malta-nrg-vs-liquid-m2-inferno.json
# There was a pause called by daps:  .pause at tick 9270
# There was a pause called by nitr0:  !pause at tick 176189
# There was a pause called by daps:  .pause at tick 318613
# There was a pause called by nitr0:  !pause at tick 318661
# There was a pause called by daps:  .pause at tick 372956
# There was a pause called by daps:  .pause at tick 427595
# There was a pause called by daps:  .pause at tick 471747
# There was a pause called by nitr0:  !pause at tick 494168
# xSuperNova-CS-GO-Malta-nrg-vs-liquid-m3-mirage.json
# There was a pause called by daps:  .pause at tick 76541
# There was a pause called by nitr0:  !pause at tick 130050
# There was a pause called by daps:  .pause at tick 174574
# There was a pause called by nitr0:  !pause at tick 239078
# xThunderpick-Bitcoin-Series-2022-copenhagen-flames-vs-k23-m1-mirage.json
# xThunderpick-Bitcoin-Series-2022-copenhagen-flames-vs-k23-m2-nuke.json
# xThunderpick-Bitcoin-Series-2022-copenhagen-flames-vs-k23-m3-overpass.json
# xV4-Future-Sports-Festival-2021-big-vs-gambit-m1-ancient.json
# There was a pause called by tabseN:  !tech at tick 35837
# There was a pause called by tabseN:  !pause at tick 56642
# There was a pause called by tabseN:  !pause at tick 126183
# There was a pause called by tabseN:  !pause at tick 191846
# xV4-Future-Sports-Festival-2021-big-vs-gambit-m2-dust2.json
# There was a pause called by tabseN:  !pause at tick 136903
# There was a pause called by tabseN:  !pause at tick 326986
# There was a pause called by tabseN:  !pause at tick 410596
# There was a pause called by tabseN:  !pause at tick 433391
# xV4-Future-Sports-Festival-2021-entropiq-vs-fiend-m1-mirage.json
# There was a pause called by NickelBack:  !pause at tick 76061
# There was a pause called by bubble:  !pause at tick 127360
# There was a pause called by NickelBack:  !tech at tick 177454
# There was a pause called by El1an:  .tech at tick 177472
# There was a pause called by NickelBack:  !pause at tick 271557
# There was a pause called by NickelBack:  !pause at tick 363722
# xV4-Future-Sports-Festival-2021-entropiq-vs-fiend-m2-ancient.json
# There was a pause called by NickelBack:  !pause at tick 154635
# There was a pause called by NickelBack:  !pause at tick 217712
# xV4-Future-Sports-Festival-2021-fiend-vs-big-m1-mirage.json
# There was a pause called by tabseN:  .pause at tick 7180
# There was a pause called by k1to:  .tech at tick 7258
# There was a pause called by tabseN:  .tech at tick 7457
# There was a pause called by tabseN:  !pause at tick 188302
# There was a pause called by tabseN:  !pause at tick 225862
# There was a pause called by bubble:  !pause at tick 248328
# There was a pause called by bubble:  !pause at tick 404455
# There was a pause called by tabseN:  !pause at tick 433254
# There was a pause called by tabseN:  !pause at tick 478736
# There was a pause called by bubble:  !pause at tick 539189
# There was a pause called by tabseN:  tech? at tick 541510
# xV4-Future-Sports-Festival-2021-fiend-vs-big-m2-dust2.json
# There was a pause called by k1to:  !tech at tick 48092
# There was a pause called by tabseN:  !pause at tick 136128
# There was a pause called by tabseN:  !pause at tick 169560
# There was a pause called by bubble:  !pause at tick 190651
# There was a pause called by tabseN:  !pause at tick 282307
# There was a pause called by bubble:  !pause at tick 347824
# There was a pause called by bubble:  !pause at tick 423557
# xV4-Future-Sports-Festival-2021-gambit-vs-entropiq-m1-vertigo.json
# There was a pause called by nafany:  !pause at tick 67064
# There was a pause called by NickelBack:  !pause at tick 105317
# There was a pause called by NickelBack:  !pause at tick 143297
# xV4-Future-Sports-Festival-2021-gambit-vs-entropiq-m2-ancient.json
# There was a pause called by NickelBack:  !pause at tick 45615
# There was a pause called by NickelBack:  !pause at tick 168963
# There was a pause called by NickelBack:  !pause at tick 232761
# xV4-Future-Sports-Festival-2021-gambit-vs-entropiq-m3-overpass.json
# There was a pause called by NickelBack:  !pause at tick 194570
# There was a pause called by NickelBack:  !pause at tick 216845
# There was a pause called by NickelBack:  !pause at tick 354990
# There was a pause called by NickelBack:  !pause at tick 399707
# xV4-Future-Sports-Festival-2021-gambit-vs-entropiq-m4-mirage.json
# There was a pause called by NickelBack:  !pause at tick 139014
# There was a pause called by NickelBack:  !pause at tick 286929
# xV4-Future-Sports-Festival-2021-gambit-vs-entropiq-m5-dust2.json
# There was a pause called by NickelBack:  !tech at tick 9554
# There was a pause called by NickelBack:  !unpause at tick 10690
# There was a pause called by nafany:  .unpause at tick 11248
# There was a pause called by NickelBack:  !pause at tick 46870
# There was a pause called by NickelBack:  !pause at tick 83432
# There was a pause called by NickelBack:  !pause at tick 112197
# There was a pause called by NickelBack:  !pause at tick 182220
# xV4-Future-Sports-Festival-2021-gambit-vs-fiend-dust2.json
# There was a pause called by interz:  tech at tick 94277
# There was a pause called by interz:  .tech at tick 94770
# There was a pause called by nafany:  need unpause to check it  at tick 103786
# There was a pause called by bubble:  !pause at tick 167884
# There was a pause called by Ax1Le:  tech at tick 195556
# There was a pause called by nafany:  tech at tick 195658
# There was a pause called by bubble:  !pause at tick 318390
# There was a pause called by bubble:  .pause at tick 379775
# xV4-Future-Sports-Festival-2021-movistar-riders-vs-fiend-m1-nuke.json
# There was a pause called by bubble:  !pause at tick 44850
# There was a pause called by h4rn:  tech at tick 45286
# There was a pause called by bubble:  .tech at tick 45436
# xV4-Future-Sports-Festival-2021-movistar-riders-vs-fiend-m2-mirage.json
# There was a pause called by bubble:  .tech at tick 13208
# There was a pause called by REDS7AR:  .unpause at tick 15969
# There was a pause called by mopoz:  .unpause at tick 16571
# There was a pause called by bubble:  .pause at tick 98458
# There was a pause called by h4rn:  .tech at tick 173662
# There was a pause called by bubble:  .pause at tick 195098
# xxBLAST-Premier-Fall-2020-Finals-astralis-vs-g2-m1-inferno-p1.json
# There was a pause called by AmaNEk:  .tech at tick 56682
# There was a pause called by kennyS:  !pause at tick 56702
# There was a pause called by huNter-:  !pause at tick 56716
# There was a pause called by Magisk:  u unpause at tick 76222
# There was a pause called by huNter-:  !unpause at tick 76632
# There was a pause called by device:  !pause at tick 77135
# There was a pause called by AmaNEk:  !pause at tick 77233
# There was a pause called by dupreeh:  just pause if it messes up again at tick 219070
# xxBLAST-Premier-Fall-2020-Finals-astralis-vs-g2-m1-inferno-p2.json
# There was a pause called by NiKo :  !pause at tick 6179
# There was a pause called by device:  !pause at tick 11504
# There was a pause called by NiKo :  !pause at tick 11549
# There was a pause called by device:  !pause at tick 12927
# xxBLAST-Premier-Fall-2020-Finals-astralis-vs-g2-m2-dust2.json
# xxBLAST-Premier-Fall-2020-Finals-astralis-vs-natus-vincere-m1-inferno.json
# There was a pause called by device:  !tech at tick 18390
# There was a pause called by device:  !pause at tick 18622
# There was a pause called by device:  !pause at tick 22812
# There was a pause called by electronic:  !pause at tick 147679
# There was a pause called by device:  !pause at tick 546715
# xxBLAST-Premier-Fall-2020-Finals-astralis-vs-natus-vincere-m2-train.json
# xxBLAST-Premier-Fall-2020-Finals-big-vs-astralis-m1-nuke.json
# xxBLAST-Premier-Fall-2020-Finals-big-vs-astralis-m2-dust2.json
# xxBLAST-Premier-Fall-2020-Finals-furia-vs-natus-vincere-m1-inferno.json
# xxBLAST-Premier-Fall-2020-Finals-furia-vs-natus-vincere-m2-nuke.json
# xxBLAST-Premier-Fall-2020-Finals-furia-vs-og-m1-inferno.json
# There was a pause called by NBK-:  !pause at tick 53193
# There was a pause called by VINI:  .tech at tick 86323
# There was a pause called by arT:  .tech at tick 86389
# There was a pause called by KSCERATO:  !pause at tick 86433
# There was a pause called by arT:  !pause at tick 90847
# xxBLAST-Premier-Fall-2020-Finals-furia-vs-og-m2-mirage.json
# xxBLAST-Premier-Fall-2020-Finals-furia-vs-og-m3-nuke.json
# There was a pause called by arT:  !pause at tick 69947
# There was a pause called by arT:  !pause at tick 70914
# There was a pause called by arT:  !pause at tick 173849
# There was a pause called by arT:  !pause at tick 179890
# There was a pause called by arT:  !pause at tick 182220
# xxBLAST-Premier-Fall-2020-Finals-g2-vs-big-m1-inferno.json
# There was a pause called by NiKo :  .tech at tick 50512
# There was a pause called by kennyS:  .technicalpause at tick 50919
# There was a pause called by nexa:  !pause at tick 50923
# There was a pause called by kennyS:  .readytoremovethetechnical at tick 52883
# There was a pause called by kennyS:  !pause at tick 53979
# There was a pause called by kennyS:  tech at tick 350418
# There was a pause called by AmaNEk:  .tech at tick 350423
# There was a pause called by NiKo :  !pause at tick 350459
# There was a pause called by kennyS:  !pause at tick 378499
# xxBLAST-Premier-Fall-2020-Finals-g2-vs-big-m2-dust2.json
# xxBLAST-Premier-Fall-2020-Finals-g2-vs-big-m3-mirage.json
# There was a pause called by tabseN:  !pause at tick 372432
# There was a pause called by tabseN:  tech kito loss at tick 372785
# There was a pause called by tabseN:  !pause at tick 427676
# xxBLAST-Premier-Fall-2020-Finals-g2-vs-furia-m1-inferno.json
# xxBLAST-Premier-Fall-2020-Finals-g2-vs-furia-m2-mirage.json
# xxBLAST-Premier-Fall-2020-Finals-g2-vs-furia-m3-nuke.json
# xxBLAST-Premier-Fall-2020-Finals-mousesports-vs-astralis-m1-nuke.json
# There was a pause called by Bymas:  tech at tick 57486
# There was a pause called by chrisJ:  .tech at tick 57495
# There was a pause called by Bymas:  !pause at tick 57594
# There was a pause called by gla1ve:  .tech at tick 151041
# There was a pause called by device:  !pause at tick 151410
# There was a pause called by device:  !pause at tick 154789
# There was a pause called by gla1ve:  .unpause at tick 154827
# There was a pause called by ropz:  !pause at tick 215163
# xxBLAST-Premier-Fall-2020-Finals-mousesports-vs-astralis-m2-vertigo.json

# %%
df["gameRounds"][0]
