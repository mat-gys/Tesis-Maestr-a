# %% [markdown]
# # Functions to generate frame states

# %%
# Although I have made some minor modifications, this part of the code was given to me by Peter Xenopoulos
import lzma
import json

# Function to read .xz archives from ESTA
def read_parsed_demo(filename):
  with lzma.LZMAFile(filename, "rb") as f:
    d = json.load(f)
    return d

def generate_vector_state(frame, map_name):
    """Returns a game state in a dictionary format.

    Args:
        frame (dict) : Dict output of a frame generated from the DemoParser class
        map_name (string): String indicating the map name

    Returns:
        A dict with keys for each feature.
    """
    game_state = {}
    game_state["mapName"] = map_name
    game_state["secondsSincePhaseStart"] = frame["seconds"]
    game_state["bombPlanted"] = frame["bombPlanted"]
    game_state["bombsite"] = frame["bombsite"]
    game_state["totalSmokes"] = len(frame["smokes"])
    game_state["totalFires"] = len(frame["fires"])

    # Team specific info (CT)
    game_state["ctAlive"] = 0
    game_state["ctHp"] = 0
    game_state["ctArmor"] = 0
    game_state["ctHelmet"] = 0
    game_state["ctEq"] = 0
    game_state["ctUtility"] = 0
    game_state["ctEqValStart"] = 0
    game_state["ctBombZone"] = 0
    game_state["defusers"] = 0
    game_state["ctNone"] = 0
    game_state["ctCash"] = 0
    if frame["ct"]["players"] != None:
        for p in frame["ct"]["players"]:
            game_state["ctEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["ctCash"] += p["cash"]
            if p["isAlive"]:
                game_state["ctAlive"] += 1
                game_state["ctHp"] += p["hp"]
                game_state["ctArmor"] += p["armor"]
                game_state["ctHelmet"] += p["hasHelmet"]
                game_state["ctEq"] += p["equipmentValue"]
                game_state["ctUtility"] += p["totalUtility"]
                game_state["defusers"] += p["hasDefuse"]
                if p["isInBombZone"]:
                    game_state["ctBombZone"] += 1
    else: 
        game_state["ctNone"] = 1

    # Team specific info (T)
    game_state["tAlive"] = 0
    game_state["tHp"] = 0
    game_state["tArmor"] = 0
    game_state["tHelmet"] = 0
    game_state["tEq"] = 0
    game_state["tUtility"] = 0
    game_state["tEqValStart"] = 0
    game_state["tHoldingBomb"] = 0
    game_state["tBombZone"] = 0
    game_state["tNone"] = 0
    game_state["tCash"] = 0
    if frame["t"]["players"] != None:
        for p in frame["t"]["players"]:
            game_state["tEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["tCash"] += p["cash"]
            if p["isAlive"]:
                game_state["tAlive"] += 1
                game_state["tHp"] += p["hp"]
                game_state["tArmor"] += p["armor"]
                game_state["tHelmet"] += p["hasHelmet"]
                game_state["tEq"] += p["equipmentValue"]
                game_state["tUtility"] += p["totalUtility"]
                if p["isInBombZone"]:
                    game_state["tBombZone"] += 1
                if p["hasBomb"]:
                    game_state["tHoldingBomb"] = 1
    else: 
        game_state["tNone"] = 1

    return game_state

# %% [markdown]
# # Via json files

# %%
# Folder where demos are stored
#path_to_demos = "C:\\Users\\Matias\\Downloads\\esta\\data\\online"
path_to_demos = "..\\input"
path_to_json = "..\\jsons"
# Folder to output dataframe
output = "..\\output"
# Folder with txt file for demos to view
path_to_txt = "..\\Demos_a_revisar.txt"

# %%
'''
Parsing games, compressing json file, compressing it and deleting .dem files
'''
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os, shutil
import patoolib
import zipfile
from zipfile import ZipFile

os.chdir(path_to_demos)

# Main dataframe
round_state_df = pd.DataFrame()

carpetas = []
for file in os.listdir():
    if ".rar" in file:
        patoolib.extract_archive("%s" % file, outdir="%s" %path_to_demos)

    # Grab demo names
    demos = []
    for demo in os.listdir():
        if (".dem" in demo) and (demo[0]!="x"):
            os.rename(demo, "x" + file.split("vs")[0] + "vs" + demo.split("vs")[1])
            demos += ["x" + file.split("vs")[0] + "vs" + demo.split("vs")[1]]
        if ".json" in demo:
            os.remove(demo)
            
    ### Itero parser over demos
    for demo in demos:
        demo_parser = DemoParser(
        demofile = "%s" % demo,
        parse_rate=128, 
        buy_style="hltv",
        parse_chat = True
        )
    
        try:
            # Parse the demofile, output results to dictionary
            df = demo_parser.parse(return_type="json")
    
            print(f"{demo[1:-4]}")
            os.remove(demo)
            shutil.move(f'x{demo[1:-4]}.json', f"{path_to_json}")
            
        except Exception as e:
            print(e)
            continue
    
    os.remove(file)
# Out:
# patool: Extracting blast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-bo3-WUVPf054ITfrylPmBtp46e.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Dropbox (Personal)\MaE\input\blast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-bo3-WUVPf054ITfrylPmBtp46e.rar"
# patool:     with cwd=..\input
# patool: ... blast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-bo3-WUVPf054ITfrylPmBtp46e.rar extracted to `..\input'.
# blast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-m1-mirage
# blast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-m2-overpass
# blast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-m3-nuke
# patool: Extracting blast-premier-fall-groups-2023-faze-vs-g2-bo3-ghH83ofICHkweejWhDNwHs.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Dropbox (Personal)\MaE\input\blast-premier-fall-groups-2023-faze-vs-g2-bo3-ghH83ofICHkweejWhDNwHs.rar"
# patool:     with cwd=..\input
# patool: ... blast-premier-fall-groups-2023-faze-vs-g2-bo3-ghH83ofICHkweejWhDNwHs.rar extracted to `..\input'.
# blast-premier-fall-groups-2023-faze-vs-g2-m1-nuke
# blast-premier-fall-groups-2023-faze-vs-g2-m2-mirage
# patool: Extracting blast-premier-fall-groups-2023-faze-vs-liquid-bo3-baXpV-xGqlE-U81KeodtL2.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Dropbox (Personal)\MaE\input\blast-premier-fall-groups-2023-faze-vs-liquid-bo3-baXpV-xGqlE-U81KeodtL2.rar"
# patool:     with cwd=..\input
# patool: ... blast-premier-fall-groups-2023-faze-vs-liquid-bo3-baXpV-xGqlE-U81KeodtL2.rar extracted to `..\input'.
# blast-premier-fall-groups-2023-faze-vs-liquid-m1-inferno
# blast-premier-fall-groups-2023-faze-vs-liquid-m2-mirage
# blast-premier-fall-groups-2023-faze-vs-liquid-m3-ancient
# patool: Extracting blast-premier-fall-groups-2023-g2-vs-liquid-bo3-cSc5E6wFfiUkPCqcnFKmx4.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Dropbox (Personal)\MaE\input\blast-premier-fall-groups-2023-g2-vs-liquid-bo3-cSc5E6wFfiUkPCqcnFKmx4.rar"
# patool:     with cwd=..\input
# patool: ... blast-premier-fall-groups-2023-g2-vs-liquid-bo3-cSc5E6wFfiUkPCqcnFKmx4.rar extracted to `..\input'.
# blast-premier-fall-groups-2023-g2-vs-liquid-m1-ancient
# blast-premier-fall-groups-2023-g2-vs-liquid-m2-mirage
# blast-premier-fall-groups-2023-g2-vs-liquid-m3-vertigo
# patool: Extracting blast-premier-fall-groups-2023-liquid-vs-faze-bo3-dC9zf7_Tm840F5g25yboK2.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Dropbox (Personal)\MaE\input\blast-premier-fall-groups-2023-liquid-vs-faze-bo3-dC9zf7_Tm840F5g25yboK2.rar"
# patool:     with cwd=..\input
# patool: ... blast-premier
rar"
# patool:     with cwd=..\input
# patool: ... iem-rio-2023-vitality-vs-heroic-bo3.rar extracted to `..\input'.
# iem-rio-2023-vitality-vs-heroic-m1-vertigo
# iem-rio-2023-vitality-vs-heroic-m2-inferno
# patool: Extracting iem-rio-2023-vitality-vs-og-overpass.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- "C:\Users\Matias\Dropbox (Personal)\MaE\input\iem-rio-2023-vitality-vs-og-overpass.rar"
# patool:     with cwd=..\input
# patool: ... iem-rio-2023-vitality-vs-og-overpass.rar extracted to `..\input'.
# iem-rio-2023-vitality-vs-og-overpass

# %%
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os, shutil
import patoolib
import json
import lzma


os.chdir("..\\jsons")

# Main dataframe
round_state_df = pd.DataFrame()

# Grab demo names
demos = []
for demo in os.listdir():
    if ".json" in demo:
        print(f"{demo}")
        with open(demo, encoding="utf-8") as demo_json:
                df = json.load(demo_json)
        #with open(demo, encoding = 'Latin-1') as f:
        #    df = json.load(f)
    # Grab round end frames (last frame of every round)
        frames = []
        iteration = 1
        for ronda in df["gameRounds"]:
            for f in ronda["frames"]:
                if f["clockTime"] == "01:55":
                    frames.append(ronda["frames"][-1])
                    break
        mapa = df["mapName"]
        
    
        # Generate vectors for each frame and pass them to df
        states = []
        for f in frames:
            game_state = generate_vector_state(f, mapa)
            states.append(game_state)
        states = pd.DataFrame(states)
        states["matchID"] = (demo[:-4])
        
        try:
            # Get total freeze time
            freezeTimeEnd = []
            startTick = []
            ctTeam = []
            tTeam = []
            winningSide = []
            for round in df["gameRounds"]:
                freezeTimeEnd.append(round["freezeTimeEndTick"])
                startTick.append(round["startTick"])
                ctTeam.append(round["ctTeam"])
                tTeam.append(round["tTeam"])
                winningSide.append(round["winningSide"])

            states["freezeTimeEndTick"] = freezeTimeEnd
            states["startTick"] = startTick
            states["ctTeam"] = ctTeam
            states["tTeam"] = tTeam
            states["winningSide"] = winningSide
            states["freezeTimeTotal"] = states["freezeTimeEndTick"] - states["startTick"] 
            states["pause"] = 0
            states["player"] = ""
            states["msg"] = ""

            # Iterate over messages, if they include a mention of a pause (either include word "pause" or "tech"), then:
            #    If msgtick >= freezeTimeEndTick ==> pause = 1 in current roundnum + 1

            for msg in df['chatMessages']:

                if msg['params'] is not None:
                    if "tech" in msg["text"] or "pause" in msg["text"]:
                        print(f'There was a pause called by {msg["params"][0]}:  {msg["text"]} at tick {msg["tick"]}' )
                        index = states.index[states["freezeTimeEndTick"]>=msg["tick"]][0]
                        if states["pause"].loc[index] == 0:
                            states.loc[index, "pause"] = 1
                            states.loc[index, "player"] = msg["params"][0]
                            states.loc[index, "msg"] = msg["text"]
                            
                if msg['params'] is None:
                    if "A player disconnected, auto pausing." in msg["text"] or "Waiting for both teams and admin to ready to continue." in msg["text"]:
                        index = states.index[states["freezeTimeEndTick"]>=msg["tick"]][0]
                        if states["pause"].loc[index] == 0:
                            states.loc[index, "pause"] = 1
                            states.loc[index, "player"] = "Admin"
                            states.loc[index, "msg"] = msg["text"]
                        
                            
            for i in range(0,5):
                states[f"ct_p{i+1}"] = ""
                states[f"t_p{i+1}"] = ""   
                states.loc[0:15, f"ct_p{i+1}"] = df["gameRounds"][0]["ctSide"]["players"][i]["playerName"]
                states.loc[0:15, f"t_p{i+1}"]  = df["gameRounds"][0]["tSide"]["players"][i]["playerName"]
                states.loc[15:, f"ct_p{i+1}"]  = df["gameRounds"][0]["tSide"]["players"][i]["playerName"]
                states.loc[15:, f"t_p{i+1}"]  = df["gameRounds"][0]["ctSide"]["players"][i]["playerName"]

        except:
            states["mismatch"] = 0
            
            for msg in df['chatMessages']:

                if msg['params'] is not None:
                    if "tech" in msg["text"] or "pause" in msg["text"]:
                        states.loc[:, "mismatch"] = 1
        
        round_state_df = pd.concat([round_state_df, pd.DataFrame(states)])
        
round_state_df.reset_index(inplace = True)
round_state_df["roundNum"] = round_state_df["index"] + 1
round_state_df.drop("index", axis = 1, inplace = True)

with pd.ExcelWriter(
    f"{output}\\parsed.xlsx",
    mode = "w",
    engine = "xlsxwriter"
) as writer:
    round_state_df.to_excel(writer, index = False, startrow = 85374, header = True)
# Out:
# xblast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-m1-mirage.json
# xblast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-m2-overpass.json
# xblast-premier-fall-groups-2023-complexity-vs-ninjas-in-pyjamas-m3-nuke.json
# xblast-premier-fall-groups-2023-faze-vs-g2-m1-nuke.json
# There was a pause called by NiKo:  .pause at tick 255891
# There was a pause called by NiKo:  !pause at tick 256065
# xblast-premier-fall-groups-2023-faze-vs-g2-m2-mirage.json
# There was a pause called by ropz:  !pause at tick 170105
# xblast-premier-fall-groups-2023-faze-vs-liquid-m1-inferno.json
# xblast-premier-fall-groups-2023-faze-vs-liquid-m2-mirage.json
# xblast-premier-fall-groups-2023-faze-vs-liquid-m3-ancient.json
# xblast-premier-fall-groups-2023-g2-vs-liquid-m1-ancient.json
# There was a pause called by HooXi:  !pause at tick 366256
# There was a pause called by NiKo:  !pause at tick 366270
# xblast-premier-fall-groups-2023-g2-vs-liquid-m2-mirage.json
# xblast-premier-fall-groups-2023-g2-vs-liquid-m3-vertigo.json
# xblast-premier-fall-groups-2023-liquid-vs-faze-m1-overpass.json
# There was a pause called by karrigan:  .tech at tick 63618
# There was a pause called by ropz:  !pause at tick 63639
# xblast-premier-fall-groups-2023-liquid-vs-faze-m2-ancient.json
# There was a pause called by karrigan:  !pause at tick 186759
# There was a pause called by karrigan:  .tech at tick 187133
# xblast-premier-fall-groups-2023-vitality-vs-ninjas-in-pyjamas-m1-mirage.json
# xblast-premier-fall-groups-2023-vitality-vs-ninjas-in-pyjamas-m2-overpass.json
# xblast-premier-spring-final-2023-faze-vs-astralis-m1-overpass.json
# xblast-premier-spring-final-2023-faze-vs-astralis-m2-mirage.json
# xblast-premier-spring-final-2023-g2-vs-cloud9-m1-vertigo.json
# There was a pause called by nafany:  .tech at tick 5300
# There was a pause called by nafany:  .tech at tick 42899
# There was a pause called by nafany:  !pause at tick 43288
# xblast-premier-spring-final-2023-g2-vs-cloud9-m2-inferno.json
# There was a pause called by HooXi:  .tech at tick 371349
# There was a pause called by huNter:  !pause at tick 371529
# xblast-premier-spring-final-2023-g2-vs-vitality-m1-anubis.json
# There was a pause called by m0NESY:  !pause at tick 7445
# xblast-premier-spring-final-2023-g2-vs-vitality-m2-inferno.json
# There was a pause called by HooXi:  !pause at tick 324943
# There was a pause called by HooXi:  !pause at tick 352989
# There was a pause called by HooXi:  pause pls at tick 353587
# xblast-premier-spring-final-2023-g2-vs-vitality-m3-nuke.json
# There was a pause called by NiKo:  !pause at tick 1958
# There was a pause called by HooXi:  !pause at tick 2786
# There was a pause called by NiKo:  .pause at tick 2883
# There was a pause called by HooXi:  !pause at tick 182389
# xblast-premier-spring-final-2023-heroic-vs-faze-m1-nuke.json
# xblast-premier-spring-final-2023-heroic-vs-faze-m2-inferno.json
# xblast-premier-spring-final-2023-heroic-vs-vitality-m1-vertigo.json
# There was a pause called by apEX:  !pause at tick 156176
# xblast-premier-spring-final-2023-heroic-vs-vitality-m2-mirage.json
# xblast-premier-spring-final-2023-heroic-vs-vitality-m3-inferno.json
# There was a pause called by ZywOo:  !pause at tick 391729
# xblast-premier-spring-final-2023-vitality-vs-cloud9-m1-overpass.json
# There was a pause called by Ax1Le:  .tech at tick 26861
# There was a pause called by nafany:  !pause at tick 27204
# xblast-premier-spring-final-2023-vitality-vs-cloud9-m2-anubis.json
# There was a pause called by Magisk:  pause at tick 141033
# There was a pause called by sh1ro:  tech at tick 141567
# xblast-premier-spring-final-2023-vitality-vs-faze-m1-anubis.json
# xblast-premier-spring-final-2023-vitality-vs-faze-m2-mirage.json
# xblasttv-paris-major-2023-9ine-vs-faze-m1-inferno.json
# There was a pause called by hades:  !tech at tick 7632
# xblasttv-paris-major-2023-9ine-vs-faze-m2-anubis.json
# xblasttv-paris-major-2023-9ine-vs-liquid-inferno.json
# There was a pause called by nitr0:  tech at tick 48148
# There was a pause called by EliGE:  .tech at tick 48268
# There was a pause called by nitr0:  !tech at tick 48614
# There was a pause called by EliGE:  .tech at tick 88142
# There was a pause called by EliGE:  !tech at tick 88339
# There was a pause called by EliGE:  !pause at tick 88553
# xblasttv-paris-major-2023-americas-rmr-pain-vs-furia-m1-overpass.json
# There was a pause called by drop:  !pause at tick 13347
# There was a pause called by drop:  !pause at tick 14780
# There was a pause called by drop:  !pause at tick 15398
# There was a pause called by drop:  pause pls  at tick 15723
# There was a pause called by NEKIZ:  !pause at tick 16056
# There was a pause called by hardzao:  !pause at tick 17477
# xblasttv-paris-major-2023-americas-rmr-pain-vs-furia-m2-vertigo.json
# There was a pause called by biguzera:  !pause at tick 40190
# There was a pause called by hardzao:  !pause at tick 44497
# xblasttv-paris-major-2023-americas-rmr-pain-vs-furia-m3-mirage.json
# xblasttv-paris-major-2023-apeks-vs-ninjas-in-pyjamas-m1-vertigo.json
# xblasttv-paris-major-2023-apeks-vs-ninjas-in-pyjamas-m2-ancient.json
# xblasttv-paris-major-2023-bad-news-eagles-vs-ence-vertigo.json
# xblasttv-paris-major-2023-bad-news-eagles-vs-g2-ancient.json
# xblasttv-paris-major-2023-challengers-europe-last-chance-qualifier-cloud9-vs-big-m1-anubis.json
# xblasttv-paris-major-2023-challengers-europe-last-chance-qualifier-cloud9-vs-big-m2-vertigo.json
# xblasttv-paris-major-2023-challengers-europe-last-chance-qualifier-faze-vs-cloud9-m1-mirage.json
# There was a pause called by karrigan:  .tech at tick 256778
# xblasttv-paris-major-2023-challengers-europe-last-chance-qualifier-faze-vs-cloud9-m2-inferno.json
# xblasttv-paris-major-2023-challengers-stage-complexity-vs-g2-inferno.json
# xblasttv-paris-major-2023-challengers-stage-complexity-vs-liquid-m1-anubis.json
# xblasttv-paris-major-2023-challengers-stage-complexity-vs-liquid-m2-overpass.json
# xblasttv-paris-major-2023-challengers-stage-complexity-vs-pain-nuke.json
# There was a pause called by floppy:  !pause at tick 8402
# There was a pause called by JT:  !pause at tick 9011
# xblasttv-paris-major-2023-challengers-stage-ence-vs-faze-m1-overpass.json
# xblasttv-paris-major-2023-challengers-stage-ence-vs-faze-m2-nuke.json
# There was a pause called by Snappi:  .tech at tick 1298
# xblasttv-paris-major-2023-challengers-stage-ence-vs-faze-m3-anubis.json
# xblasttv-paris-major-2023-challengers-stage-ence-vs-ninjas-in-pyjamas-vertigo.json
# xblasttv-paris-major-2023-challengers-stage-faze-vs-forze-m1-overpass.json
# xblasttv-paris-major-2023-challengers-stage-faze-vs-forze-m2-nuke.json
# xblasttv-paris-major-2023-challengers-stage-faze-vs-pain-nuke.json
# There was a pause called by biguzera:  .tech at tick 35713
# There was a pause called by hardzao:  !pause at tick 36342
# xblasttv-paris-major-2023-challengers-stage-forze-vs-liquid-nuke.json
# xblasttv-paris-major-2023-challengers-stage-mouz-vs-og-ancient.json
# xblasttv-paris-major-2023-challengers-stage-ninjas-in-pyjamas-vs-mouz-mirage.json
# xblasttv-paris-major-2023-challengers-stage-ninjas-in-pyjamas-vs-og-mirage.json
# xblasttv-paris-major-2023-challengers-stage-og-vs-ence-anubis.json
# There was a pause called by dycha:  .tech at tick 22770
# There was a pause called by dycha:  .tech at tick 23223
# There was a pause called by flameZ:   ! pause at tick 23290
# There was a pause called by Snappi:  !pause at tick 23603
# There was a pause called by degster:  !pause at tick 40276
# There was a pause called by degster:  !pause at tick 75209
# There was a pause called by flameZ:  !pause at tick 75821
# There was a pause called by degster:  !pause at tick 179896
# xblasttv-paris-major-2023-ence-vs-ninjas-in-pyjamas-m1-mirage.json
# There was a pause called by k0nfig:  tech at tick 11109
# There was a pause called by dycha:  !pause at tick 11838
# There was a pause called by Snappi:  .pause at tick 25962
# There was a pause called by Snappi:  .tech at tick 26164
# There was a pause called by Snappi:  !pause at tick 26468
# There was a pause called by k0nfig:  .pause at tick 26521
# xblasttv-paris-major-2023-ence-vs-ninjas-in-pyjamas-m2-ancient.json
# xblasttv-paris-major-2023-europe-rmr-b-astralis-vs-spirit-m1-mirage.json
# There was a pause called by chopper:  !pause at tick 1700
# There was a pause called by magixx:  !pause at tick 1787
# There was a pause called by Xyp9x:  .tech at tick 66113
# There was a pause called by Xyp9x:  !pause at tick 66504
# There was a pause called by dev1ce:  !tech at tick 66510
# There was a pause called by dev1ce:  tech at tick 202913
# xblasttv-paris-major-2023-europe-rmr-b-astralis-vs-spirit-m2-ancient.json
# There was a pause called by Xyp9x:  .tech at tick 96954
# There was a pause called by Xyp9x:  !pause at tick 97207
# xblasttv-paris-major-2023-europe-rmr-b-astralis-vs-spirit-m3-overpass.json
# There was a pause called by dev1ce:  !tech at tick 23613
# There was a pause called by dev1ce:  !pause at tick 23969
# There was a pause called by blameF:  !pause at tick 24625
# There was a pause called by gla1ve:  !tech at tick 24929
# There was a pause called by dev1ce:  !pause at tick 25374
# There was a pause called by chopper:  !pause at tick 25772
# xblasttv-paris-major-2023-europe-rmr-b-big-vs-vitality-m1-mirage.json
# There was a pause called by tabseN:  !tech at tick 32457
# There was a pause called by tabseN:  !pause at tick 32647
# There was a pause called by tabseN:  !pause at tick 37020
# xblasttv-paris-major-2023-europe-rmr-b-big-vs-vitality-m2-nuke.json
# There was a pause called by apEX:  you called a tech they said at tick 20489
# xblasttv-paris-major-2023-europe-rmr-b-big-vs-vitality-m3-overpass.json
# There was a pause called by tabseN:  !pause at tick 159177
# xblasttv-paris-major-2023-europe-rmr-b-cloud9-vs-ence-m1-ancient.json
# xblasttv-paris-major-2023-europe-rmr-b-cloud9-vs-ence-m2-vertigo.json
# There was a pause called by dycha:  .tech at tick 55526
# There was a pause called by Snappi:  .tech at tick 55582
# There was a pause called by Snappi:  .pause at tick 55722
# There was a pause called by Snappi:  !pause at tick 55931
# There was a pause called by Snappi:  !pause at tick 59981
# xblasttv-paris-major-2023-europe-rmr-b-cloud9-vs-forze-inferno.json
# There was a pause called by nafany:  .tech at tick 68023
# There was a pause called by nafany:  .tech at tick 68473
# There was a pause called by nafany:  !pause at tick 68852
# There was a pause called by nafany:  !pause at tick 155773
# xblasttv-paris-major-2023-europe-rmr-b-cloud9-vs-g2-m1-vertigo.json
# xblasttv-paris-major-2023-europe-rmr-b-cloud9-vs-g2-m2-inferno.json
# xblasttv-paris-major-2023-europe-rmr-b-ence-vs-forze-anubis.json
# xblasttv-paris-major-2023-europe-rmr-b-g2-vs-vitality-m1-mirage.json
# xblasttv-paris-major-2023-europe-rmr-b-g2-vs-vitality-m2-anubis.json
# xblasttv-paris-major-2023-europe-rmr-b-vitality-vs-astralis-vertigo.json
# xblasttv-paris-major-2023-faze-vs-bad-news-eagles-m1-overpass.json
# xblasttv-paris-major-2023-faze-vs-bad-news-eagles-m2-mirage.json
# There was a pause called by rigoN:  .tech at tick 336032
# There was a pause called by sinnopsyy:  .pause at tick 337666
# There was a pause called by Twistzz:  !tech at tick 338146
# There was a pause called by sinnopsyy:  .tech at tick 338188
# xblasttv-paris-major-2023-faze-vs-bad-news-eagles-m3-inferno.json
# xblasttv-paris-major-2023-faze-vs-natus-vincere-m1-overpass.json
# xblasttv-paris-major-2023-faze-vs-natus-vincere-m2-mirage.json
# xblasttv-paris-major-2023-faze-vs-natus-vincere-m3-anubis.json
# xblasttv-paris-major-2023-fnatic-vs-g2-m1-inferno.json
# There was a pause called by NiKo:  why is it paused? at tick 611017
# xblasttv-paris-major-2023-fnatic-vs-g2-m2-ancient.json
# xblasttv-paris-major-2023-fnatic-vs-g2-m3-vertigo.json
# There was a pause called by KRIMZ:  .tech at tick 32198
# There was a pause called by KRIMZ:  .pause at tick 32323
# There was a pause called by nicoodoz:  !pause at tick 32341
# There was a pause called by nicoodoz:  !pause at tick 34359
# There was a pause called by nicoodoz:  !pause at tick 48559
# xblasttv-paris-major-2023-fnatic-vs-ninjas-in-pyjamas-nuke.json
# xblasttv-paris-major-2023-furia-vs-g2-m1-inferno.json
# xblasttv-paris-major-2023-furia-vs-g2-m2-mirage.json
# xblasttv-paris-major-2023-furia-vs-ninjas-in-pyjamas-nuke.json
# xblasttv-paris-major-2023-heroic-vs-faze-inferno.json
# xblasttv-paris-major-2023-heroic-vs-faze-m1-nuke.json
# xblasttv-paris-major-2023-heroic-vs-faze-m2-overpass.json
# xblasttv-paris-major-2023-heroic-vs-faze-m3-mirage.json
# xblasttv-paris-major-2023-heroic-vs-liquid-m1-inferno.json
# There was a pause called by sjuush:  !pause at tick 105729
# There was a pause called by sjuush:  !pause at tick 108511
# xblasttv-paris-major-2023-heroic-vs-liquid-m2-mirage.json
# xblasttv-paris-major-2023-heroic-vs-liquid-m3-ancient.json
# xblasttv-paris-major-2023-liquid-vs-apeks-m1-ancient.json
# xblasttv-paris-major-2023-liquid-vs-apeks-m2-overpass.json
# xblasttv-paris-major-2023-liquid-vs-natus-vincere-inferno.json
# xblasttv-paris-major-2023-natus-vincere-vs-ninjas-in-pyjamas-overpass.json
# xblasttv-paris-major-2023-vitality-vs-apeks-m1-mirage.json
# There was a pause called by kyxsan:  !tech at tick 33216
# There was a pause called by kyxsan:  !pause at tick 33376
# There was a pause called by kyxsan:  !pause at tick 43447
# xblasttv-paris-major-2023-vitality-vs-apeks-m2-vertigo.json
# xblasttv-paris-major-2023-vitality-vs-ence-vertigo.json
# xblasttv-paris-major-2023-vitality-vs-g2-nuke.json
# xbrazy-party-2023-cloud9-vs-9ine-m1-vertigo.json
# xbrazy-party-2023-cloud9-vs-9ine-m2-ancient.json
# xbrazy-party-2023-cloud9-vs-9ine-m3-overpass.json
# There was a pause called by mynio:  !tech at tick 244066
# There was a pause called by mynio:  .unpause at tick 257838
# There was a pause called by nafany:  .tech at tick 607008
# xbrazy-party-2023-cloud9-vs-pain-m1-ancient.json
# xbrazy-party-2023-cloud9-vs-pain-m2-anubis.json
# There was a pause called by nafany:  .tech at tick 241528
# There was a pause called by nafany:  .unpause at tick 248932
# xbrazy-party-2023-pain-vs-big-m1-mirage.json
# xbrazy-party-2023-pain-vs-big-m2-nuke.json
# There was a pause called by prosus:  .tech at tick 32494
# There was a pause called by hardzao:  .tech at tick 378963
# xbrazy-party-2023-pain-vs-big-m3-vertigo.json
# xcct-2023-online-finals-1-big-vs-9ine-m1-anubis.json
# There was a pause called by tabseN:  !tech at tick 17144
# There was a pause called by Krimbo:  !unpause at tick 20049
# There was a pause called by hades:  !unpause at tick 20644
# There was a pause called by tabseN:  !tech at tick 110756
# There was a pause called by tabseN:  !unpause at tick 115007
# There was a pause called by hades:  !unpause at tick 115303
# xcct-2023-online-finals-1-big-vs-9ine-m2-nuke.json
# xcct-2023-online-finals-1-into-the-breach-vs-big-m1-vertigo.json
# There was a pause called by tabseN:  !tech at tick 16216
# There was a pause called by tabseN:  !unpause at tick 19846
# xcct-2023-online-finals-1-into-the-breach-vs-big-m2-anubis.json
# xcct-2023-online-finals-1-into-the-breach-vs-big-m3-mirage.json
# There was a pause called by Krimbo:  .tech at tick 57926
# xcct-2023-online-finals-1-ninjas-in-pyjamas-vs-into-the-breach-m1-vertigo.json
# There was a pause called by k0nfig:  .tech at tick 222644
# xcct-2023-online-finals-1-ninjas-in-pyjamas-vs-into-the-breach-m2-mirage.json
# xcct-2023-online-finals-1-ninjas-in-pyjamas-vs-into-the-breach-m3-inferno.json
# There was a pause called by Thomas:  !tech at tick 47844
# There was a pause called by volt:  !unpause at tick 51758
# There was a pause called by k0nfig:  !unpause at tick 52936
# There was a pause called by Brollan:  .tech at tick 265387
# xelisa-invitational-spring-2023-apeks-vs-mouz-m1-mirage.json
# There was a pause called by jkaem:  !pause at tick 30112
# There was a pause called by jkaem:  !tech at tick 30678
# There was a pause called by jL:  .tech at tick 40620
# There was a pause called by jL:  .unpause at tick 41107
# There was a pause called by dexter:  .unpause at tick 41420
# xelisa-invitational-spring-2023-apeks-vs-mouz-m2-vertigo.json
# xelisa-invitational-spring-2023-into-the-breach-vs-apeks-m1-ancient.json
# There was a pause called by kyxsan:  !tech at tick 22252
# There was a pause called by kyxsan:  !unpause at tick 28277
# There was a pause called by jkaem:  .tech at tick 241576
# There was a pause called by volt:  !unpause at tick 246072
# There was a pause called by jkaem:  !unpause at tick 246662
# xelisa-invitational-spring-2023-into-the-breach-vs-apeks-m2-inferno.json
# xelisa-invitational-spring-2023-into-the-breach-vs-apeks-m3-mirage.json
# xesl-challenger-katowice-2023-europe-closed-qualifier-big-vs-ninjas-in-pyjamas-m1-mirage.json
# There was a pause called by k0nfig:  .tech at tick 119161
# There was a pause called by Brollan:  .tech at tick 181898
# There was a pause called by k0nfig:  .tech at tick 181953
# There was a pause called by tabseN:  !tech at tick 181997
# xesl-challenger-katowice-2023-europe-closed-qualifier-big-vs-ninjas-in-pyjamas-m2-overpass.json
# xesl-challenger-katowice-2023-europe-closed-qualifier-big-vs-ninjas-in-pyjamas-m3-vertigo.json
# xesl-challenger-katowice-2023-forze-vs-ence-m1-nuke.json
# There was a pause called by r3salt:  .techn at tick 9954
# There was a pause called by r3salt:  .tech at tick 10197
# There was a pause called by shalfey:  .tech at tick 73118
# There was a pause called by r3salt:  .tech at tick 78116
# There was a pause called by shalfey:  .tech at tick 78248
# xesl-challenger-katowice-2023-forze-vs-ence-m2-overpass.json
# xesl-challenger-league-season-45-europe-apeks-vs-monte-m1-ancient.json
# xesl-challenger-league-season-45-europe-apeks-vs-monte-m2-mirage.json
# xesl-challenger-league-season-45-europe-apeks-vs-monte-m3-anubis.json
# xiem-dallas-2023-ence-vs-faze-m1-mirage.json
# There was a pause called by dycha:  !pause at tick 10596
# There was a pause called by Snappi:  .tech at tick 10709
# There was a pause called by Snappi:  .tech at tick 77072
# There was a pause called by Snappi:  .tech at tick 93923
# xiem-dallas-2023-ence-vs-faze-m2-anubis.json
# xiem-dallas-2023-ence-vs-faze-m3-ancient.json
# xiem-dallas-2023-faze-vs-cloud9-m1-mirage.json
# xiem-dallas-2023-faze-vs-cloud9-m2-inferno.json
# xiem-dallas-2023-faze-vs-cloud9-m3-ancient.json
# There was a pause called by nafany:  .tech at tick 210013
# There was a pause called by nafany:  .tech at tick 275201
# xiem-dallas-2023-faze-vs-ence-m1-anubis.json
# There was a pause called by Snappi:  .tech at tick 53912
# There was a pause called by karrigan:  .tech at tick 81570
# xiem-dallas-2023-faze-vs-ence-m2-overpass.json
# xiem-dallas-2023-faze-vs-liquid-m1-anubis.json
# There was a pause called by karrigan:  .tech at tick 59037
# xiem-dallas-2023-faze-vs-liquid-m2-nuke.json
# xiem-dallas-2023-fnatic-vs-mouz-nuke.json
# xiem-dallas-2023-furia-vs-mouz-m1-inferno.json
# xiem-dallas-2023-furia-vs-mouz-m2-vertigo.json
# xiem-dallas-2023-furia-vs-og-inferno.json
# xiem-dallas-2023-g2-vs-faze-m1-ancient.json
# There was a pause called by ropz:  .tech at tick 358190
# xiem-dallas-2023-g2-vs-faze-m2-inferno.json
# xiem-dallas-2023-g2-vs-faze-m3-mirage.json
# xiem-dallas-2023-g2-vs-heroic-m1-inferno.json
# xiem-dallas-2023-g2-vs-heroic-m2-ancient.json
# xiem-dallas-2023-g2-vs-og-m1-mirage.json
# xiem-dallas-2023-g2-vs-og-m2-inferno.json
# xiem-dallas-2023-heroic-vs-mouz-m1-vertigo.json
# There was a pause called by sjuush:  !pause at tick 13825
# There was a pause called by sjuush:  .pause at tick 14212
# There was a pause called by sjuush:  pause at tick 147195
# There was a pause called by sjuush:  .pause at tick 147363
# xiem-dallas-2023-heroic-vs-mouz-m2-overpass.json
# xiem-dallas-2023-heroic-vs-mouz-m3-ancient.json
# xiem-dallas-2023-mouz-vs-ence-m1-mirage.json
# There was a pause called by Snappi:  .tech at tick 297744
# There was a pause called by Snappi:  .tech at tick 298361
# There was a pause called by dexter:  .tech at tick 309423
# There was a pause called by frozen:  ,tech at tick 309437
# xiem-dallas-2023-mouz-vs-ence-m2-nuke.json
# xiem-dallas-2023-mouz-vs-heroic-m1-mirage.json
# xiem-dallas-2023-mouz-vs-heroic-m2-overpass.json
# xiem-dallas-2023-mouz-vs-og-m1-mirage.json
# There was a pause called by flameZ:  .tech at tick 121635
# There was a pause called by flameZ:  .tech at tick 141992
# xiem-dallas-2023-mouz-vs-og-m2-inferno.json
# xiem-rio-2023-big-vs-heroic-m1-vertigo.json
# xiem-rio-2023-big-vs-heroic-m2-nuke.json
# xiem-rio-2023-big-vs-heroic-m3-overpass.json
# xiem-rio-2023-big-vs-mouz-overpass.json
# xiem-rio-2023-cloud9-vs-vitality-m1-inferno.json
# There was a pause called by Spinx:  !tech at tick 46835
# There was a pause called by Spinx:  .tech at tick 47295
# There was a pause called by Spinx:  .tech at tick 72253
# xiem-rio-2023-cloud9-vs-vitality-m2-vertigo.json
# xiem-rio-2023-cloud9-vs-vitality-m3-overpass.json
# xiem-rio-2023-faze-vs-furia-m1-mirage.json
# xiem-rio-2023-faze-vs-furia-m2-nuke.json
# xiem-rio-2023-fnatic-vs-og-m1-mirage.json
# There was a pause called by degster:  .tech at tick 168607
# There was a pause called by flameZ:  !unpause at tick 170252
# xiem-rio-2023-fnatic-vs-og-m2-vertigo.json
# xiem-rio-2023-furia-vs-cloud9-m1-inferno.json
# There was a pause called by nafany:  .tech at tick 102844
# There was a pause called by nafany:  .tech at tick 103062
# There was a pause called by arT:  .tech at tick 460482
# xiem-rio-2023-furia-vs-cloud9-m2-vertigo.json
# xiem-rio-2023-furia-vs-cloud9-m3-ancient.json
# xiem-rio-2023-furia-vs-fnatic-ancient.json
# xiem-rio-2023-heroic-vs-furia-m1-inferno.json
# xiem-rio-2023-heroic-vs-furia-m2-mirage.json
# xiem-rio-2023-heroic-vs-furia-m3-ancient.json
# xiem-rio-2023-natus-vincere-vs-big-m1-mirage.json
# There was a pause called by tabseN:  !pause at tick 421821
# There was a pause called by k1to:  .tech at tick 421880
# There was a pause called by s1mple:  is it pause because of lights? at tick 432195
# xiem-rio-2023-natus-vincere-vs-big-m2-inferno.json
# xiem-rio-2023-natus-vincere-vs-heroic-m1-overpass.json
# There was a pause called by cadiaN:  .tech at tick 683107
# xiem-rio-2023-natus-vincere-vs-heroic-m2-ancient.json
# xiem-rio-2023-ninjas-in-pyjamas-vs-heroic-m1-overpass.json
# xiem-rio-2023-ninjas-in-pyjamas-vs-heroic-m2-inferno.json
# There was a pause called by Brollan:  !pause at tick 171614
# There was a pause called by Brollan:  .pause at tick 171815
# xiem-rio-2023-ninjas-in-pyjamas-vs-natus-vincere-m1-mirage.json
# xiem-rio-2023-ninjas-in-pyjamas-vs-natus-vincere-m2-ancient.json
# There was a pause called by REZ:  .tech at tick 178267
# xiem-rio-2023-og-vs-cloud9-m1-mirage.json
# There was a pause called by flameZ:  .tech at tick 396
# There was a pause called by nafany:  .tech at tick 56561
# There was a pause called by NEOFRAG:  .tech at tick 114895
# There was a pause called by nafany:  .tech at tick 351162
# xiem-rio-2023-og-vs-cloud9-m2-overpass.json
# There was a pause called by degster:  .tech at tick 378623
# xiem-rio-2023-og-vs-vitality-m1-mirage.json
# xiem-rio-2023-og-vs-vitality-m2-inferno.json
# There was a pause called by flameZ:  .tech at tick 314806
# xiem-rio-2023-og-vs-vitality-m3-overpass.json
# xiem-rio-2023-vitality-vs-big-m1-nuke.json
# There was a pause called by faveN:  !pause at tick 1480
# There was a pause called by Magisk:  .tech at tick 1728
# There was a pause called by faveN:  !unpause at tick 12244
# There was a pause called by faveN:  .unpause at tick 12603
# There was a pause called by Magisk:  .unpause at tick 12692
# There was a pause called by k1to:  !tech at tick 43656
# There was a pause called by k1to:  !pause at tick 43900
# There was a pause called by tabseN:  .tech at tick 44203
# xiem-rio-2023-vitality-vs-big-m2-mirage.json
# There was a pause called by Magisk:  .tech at tick 107305
# There was a pause called by Spinx:  !tech at tick 129069
# There was a pause called by Spinx:  .tech at tick 129353
# There was a pause called by apEX:  .tech at tick 237265
# xiem-rio-2023-vitality-vs-faze-m1-anubis.json
# There was a pause called by ropz:  .tech at tick 510261
# xiem-rio-2023-vitality-vs-faze-m2-overpass.json
# xiem-rio-2023-vitality-vs-heroic-m1-vertigo.json
# xiem-rio-2023-vitality-vs-heroic-m2-inferno.json
# xiem-rio-2023-vitality-vs-og-overpass.json
# There was a pause called by flameZ:  .tech at tick 57731
# There was a pause called by flameZ:  .tech at tick 57972
# There was a pause called by flameZ:  .tech at tick 532023
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 113>()
#     111 round_state_df.drop("index", axis = 1, inplace = True)
#     113 with pd.ExcelWriter(
#     114     f"{output}\\parsed.xlsx",
#     115     mode = "w",
#     116     engine = "xlsxwriter"
#     117 ) as writer:
# --> 118     round_state_df.to_excel(writer, index = False, startrow = writer.sheets['Sheet1'].max_row, header = True)
#
# KeyError: 'Sheet1'

# %%
df["gameRounds"][0]

# %%
with pd.ExcelWriter(
    f"{output}\\parsed.xlsx",
    mode = "w",
    engine = "xlsxwriter"
) as writer:
    round_state_df.to_excel(writer, index = False, startrow = 85374, header = True)
