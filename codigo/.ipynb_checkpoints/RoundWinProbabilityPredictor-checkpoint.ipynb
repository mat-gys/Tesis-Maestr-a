# %%
# Although I have made some minor modifications, this part of the code was given to me by Peter Xenopoulos
import lzma
import json

# Function to read .xz archives from ESTA
def read_parsed_demo(filename):
  with lzma.LZMAFile(filename, "rb") as f:
    d = json.load(f)
    return d

def generate_vector_state(frame, map_name):
    """Returns a game state in a dictionary format.

    Args:
        frame (dict) : Dict output of a frame generated from the DemoParser class
        map_name (string): String indicating the map name

    Returns:
        A dict with keys for each feature.
    """
    game_state = {}
    game_state["mapName"] = map_name
    game_state["secondsSincePhaseStart"] = frame["seconds"]
    game_state["bombPlanted"] = frame["bombPlanted"]
    game_state["bombsite"] = frame["bombsite"]
    game_state["totalSmokes"] = len(frame["smokes"])
    game_state["totalFires"] = len(frame["fires"])

    # Team specific info (CT)
    game_state["ctAlive"] = 0
    game_state["ctHp"] = 0
    game_state["ctArmor"] = 0
    game_state["ctHelmet"] = 0
    game_state["ctEq"] = 0
    game_state["ctUtility"] = 0
    game_state["ctEqValStart"] = 0
    game_state["ctBombZone"] = 0
    game_state["defusers"] = 0
    game_state["ctNone"] = 0
    game_state["ctCash"] = 0
    if frame["ct"]["players"] != None:
        for p in frame["ct"]["players"]:
            game_state["ctEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["ctCash"] += p["cash"]
            if p["isAlive"]:
                game_state["ctAlive"] += 1
                game_state["ctHp"] += p["hp"]
                game_state["ctArmor"] += p["armor"]
                game_state["ctHelmet"] += p["hasHelmet"]
                game_state["ctEq"] += p["equipmentValue"]
                game_state["ctUtility"] += p["totalUtility"]
                game_state["defusers"] += p["hasDefuse"]
                if p["isInBombZone"]:
                    game_state["ctBombZone"] += 1
    else: 
        game_state["ctNone"] = 1

    # Team specific info (T)
    game_state["tAlive"] = 0
    game_state["tHp"] = 0
    game_state["tArmor"] = 0
    game_state["tHelmet"] = 0
    game_state["tEq"] = 0
    game_state["tUtility"] = 0
    game_state["tEqValStart"] = 0
    game_state["tHoldingBomb"] = 0
    game_state["tBombZone"] = 0
    game_state["tNone"] = 0
    game_state["tCash"] = 0
    if frame["t"]["players"] != None:
        for p in frame["t"]["players"]:
            game_state["tEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["tCash"] += p["cash"]
            if p["isAlive"]:
                game_state["tAlive"] += 1
                game_state["tHp"] += p["hp"]
                game_state["tArmor"] += p["armor"]
                game_state["tHelmet"] += p["hasHelmet"]
                game_state["tEq"] += p["equipmentValue"]
                game_state["tUtility"] += p["totalUtility"]
                if p["isInBombZone"]:
                    game_state["tBombZone"] += 1
                if p["hasBomb"]:
                    game_state["tHoldingBomb"] = 1
    else: 
        game_state["tNone"] = 1

    return game_state

# %%
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os
import patoolib
import pickle


# Demo list to process
path_to_demos = "C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\parsedDemos"
os.chdir(path_to_demos)

carpetas = []
for file in os.listdir():
    if ".rar" in file:
        carpetas += [file]
    elif ".dem" in file or ".json" in file:
        os.remove(file)
        
    
# Now there are more files, I can iterate over the new ones
for folder in carpetas:
    # Extacting the folder
    patoolib.extract_archive("%s" % folder, outdir="%s" %path_to_demos)
    
    # Iterate over files and check whether they are a demo and I haven't changed their names. If not, I change their name
    for demo in os.listdir():
        for nombre in carpetas:
            if (".dem" not in demo) or (demo[0] == "x"):
                break
        else:
            os.rename(demo, "x" + folder.split("vs")[0] + "vs" + demo.split("vs")[1])

# Grab demo names
demos = []
for file in os.listdir():
    if ".dem" in file:
        demos += [file]

### Iterate parser over demos
round_state_df = pd.DataFrame()
for demo in demos:
    demo_parser = DemoParser(
    demofile = "%s" % demo,
    parse_rate=128, 
    buy_style="hltv"
    )


    # Parse the demofile, output results to dictionary
    df = demo_parser.parse(return_type="json")

    # Grab round start frames
    frames = []
    iteration = 1
    for ronda in df["gameRounds"]:
        for f in ronda["frames"]:
            if f["clockTime"] == "01:55":
                frames.append(ronda["frames"][-1])
                break
    mapa = df["mapName"]
    

    # Generate vectors for each frame and pass them to df
    states = []
    for f in frames:
        game_state = generate_vector_state(f, mapa)
        states.append(game_state)
    states = pd.DataFrame(states)
    states["matchID"] = (demo[:-4])
    #states.index += 1
    round_state_df = pd.concat([round_state_df, pd.DataFrame(states)])


round_state_df.reset_index(inplace = True)
round_state_df["roundNum"] = round_state_df["index"] + 1
round_state_df.drop("index", axis = 1, inplace = True)


with pd.ExcelWriter(
    "C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\output\\winProb.xlsx",
    mode = "a",
    if_sheet_exists = "overlay"
) as writer:
    round_state_df.to_excel(writer, index = False, startrow = writer.sheets['Sheet1'].max_row, header = None)

# %% [markdown]
# # Without extracting zips

# %%
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os
import patoolib
import pickle


# Demo list to process
path_to_demos = "C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\parsedDemos"
os.chdir(path_to_demos)

# Grab demo names
demos = []
for file in os.listdir():
    if ".dem" in file:
        demos += [file]

### Iterate parser over demos
round_state_df = pd.DataFrame()
for demo in demos:
    demo_parser = DemoParser(
    demofile = "%s" % demo,
    parse_rate=128, 
    buy_style="hltv"
    )


    # Parse the demofile, output results to dictionary
    df = demo_parser.parse(return_type="json")

    # Grab round finish frames (last frame of previous round for every round)
    frames = []
    iteration = 1
    for ronda in df["gameRounds"]:
        for f in ronda["frames"]:
            if f["clockTime"] == "01:55":
                frames.append(ronda["frames"][-1])
                break
    mapa = df["mapName"]
    

    # Generate vectors for each frame and pass them to df
    states = []
    for f in frames:
        game_state = generate_vector_state(f, mapa)
        states.append(game_state)
    states = pd.DataFrame(states)
    states["matchID"] = (demo[:-4])
    #states.index += 1
    round_state_df = pd.concat([round_state_df, pd.DataFrame(states)])


round_state_df.reset_index(inplace = True)
round_state_df["roundNum"] = round_state_df["index"] + 1
round_state_df.drop("index", axis = 1, inplace = True)


with pd.ExcelWriter(
    "C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\output\\winProb.xlsx",
    mode = "a",
    if_sheet_exists = "overlay"
) as writer:
    round_state_df.to_excel(writer, index = False, startrow = writer.sheets['Sheet1'].max_row, header = None)

# %% [markdown]
# ## Intento weapons

# %%
import lzma
import json

# Function to read .xz archives from ESTA
def read_parsed_demo(filename):
  with lzma.LZMAFile(filename, "rb") as f:
    d = json.load(f)
    return d

def generate_vector_state(frame, map_name):
    """Returns a game state in a dictionary format.

    Args:
        frame (dict) : Dict output of a frame generated from the DemoParser class
        map_name (string): String indicating the map name

    Returns:
        A dict with keys for each feature.
    """
    game_state = {}
    game_state["mapName"] = map_name
    game_state["secondsSincePhaseStart"] = frame["seconds"]
    game_state["bombPlanted"] = frame["bombPlanted"]
    game_state["bombsite"] = frame["bombsite"]
    game_state["totalSmokes"] = len(frame["smokes"])
    game_state["totalFires"] = len(frame["fires"])

    # Team specific info (CT)
    game_state["ctAlive"] = 0
    game_state["ctHp"] = 0
    game_state["ctArmor"] = 0
    game_state["ctHelmet"] = 0
    game_state["ctEq"] = 0
    game_state["ctUtility"] = 0
    game_state["ctEqValStart"] = 0
    game_state["ctBombZone"] = 0
    game_state["defusers"] = 0
    game_state["ctNone"] = 0
    game_state["ctCash"] = 0
    if frame["ct"]["players"] != None:
        for p in frame["ct"]["players"]:
            game_state["ctEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["ctCash"] += p["cash"]
            if p["isAlive"]:
                game_state["ctAlive"] += 1
                game_state["ctHp"] += p["hp"]
                game_state["ctArmor"] += p["armor"]
                game_state["ctHelmet"] += p["hasHelmet"]
                game_state["ctEq"] += p["equipmentValue"]
                game_state["ctUtility"] += p["totalUtility"]
                game_state["defusers"] += p["hasDefuse"]
                if p["isInBombZone"]:
                    game_state["ctBombZone"] += 1

    else: 
        game_state["ctNone"] = 1

    # Team specific info (T)
    game_state["tAlive"] = 0
    game_state["tHp"] = 0
    game_state["tArmor"] = 0
    game_state["tHelmet"] = 0
    game_state["tEq"] = 0
    game_state["tUtility"] = 0
    game_state["tEqValStart"] = 0
    game_state["tHoldingBomb"] = 0
    game_state["tBombZone"] = 0
    game_state["tNone"] = 0
    game_state["tCash"] = 0
    if frame["t"]["players"] != None:
        for p in frame["t"]["players"]:
            game_state["tEqValStart"] += p["equipmentValueFreezetimeEnd"]
            game_state["tCash"] += p["cash"]
            if p["isAlive"]:
                game_state["tAlive"] += 1
                game_state["tHp"] += p["hp"]
                game_state["tArmor"] += p["armor"]
                game_state["tHelmet"] += p["hasHelmet"]
                game_state["tEq"] += p["equipmentValue"]
                game_state["tUtility"] += p["totalUtility"]
                if p["isInBombZone"]:
                    game_state["tBombZone"] += 1
                if p["hasBomb"]:
                    game_state["tHoldingBomb"] = 1
    else: 
        game_state["tNone"] = 1

    return game_state

# %%
from openpyxl import Workbook
from awpy.parser import DemoParser
import pandas as pd
import os
import patoolib
import pickle

os.chdir("C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\parsedDemos")

demo_parser = DemoParser(
    demofile = "xBLAST-Premier-Fall-2020-Finals-vitality-vs-astralis-m1-vertigo.dem",
    parse_rate=128, 
    buy_style="hltv"
    )


# Parse the demofile, output results to dictionary
df = demo_parser.parse(return_type="json")
# Grab round finish frames (last frame of previous round for every round)
frames = []
iteration = 1
for ronda in df["gameRounds"]:
    for f in ronda["frames"]:
        if f["clockTime"] == "01:55":
            frames.append(ronda["frames"][-1])
            break
mapa = df["mapName"]

# Generate vectors for each frame and pass them to df
#states = []
#for f in frames:
#    game_state = generate_vector_state(f, mapa)
#    states.append(game_state)
#states = pd.DataFrame(states)
#states["matchID"] = (demo[:-4])
##states.index += 1
#round_state_df = pd.concat([round_state_df, pd.DataFrame(states)])
#
#
#round_state_df.reset_index(inplace = True)
#round_state_df["roundNum"] = round_state_df["index"] + 1
#round_state_df.drop("index", axis = 1, inplace = True)

# %%
weapons = ["Rifle", "Pistols", ""]
for n in range(16,20):
    for i in range(5):
        print(frames[n]['ct']['players'][i]["name"])
        try:
            for j in range(8):
                print(frames[n]['ct']['players'][i]["inventory"][j]["weaponClass"])
                print("\n")
        except:
            continue
# Out:
# Magisk
# gla1ve
# Grenade
#
#
# Pistols
#
#
# Grenade
#
#
# dupreeh
# Pistols
#
#
# Grenade
#
#
# Rifle
#
#
# device
# Pistols
#
#
# Rifle
#
#
# Xyp9x
# device
# dupreeh
# Magisk
# Pistols
#
#
# Rifle
#
#
# Grenade
#
#
# Xyp9x
# gla1ve
# device
# Xyp9x
# Magisk
# dupreeh
# gla1ve
# device
# Magisk
# gla1ve
# Grenade
#
#
# Grenade
#
#
# Pistols
#
#
# Xyp9x
# dupreeh

# %% [markdown]
# # Merging demoparser and round win probability predictors

# %%
import pandas as pd
df1 = pd.read_excel("C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\output\\winProb.xlsx")
df2 = pd.read_excel("C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\output\\parsedDemos.xlsx")

# %%
df = df1.merge(df2, how = "outer", on = ["matchID", "roundNum", "mapName"])

# %%
start_row = 0
with pd.ExcelWriter(
    "C:\\Users\\Matias\\Documents\\UDESA\\Tesis_maestria\\Replication files\\output\\final.xlsx",
    mode = "w"
) as writer:
    df.to_excel(writer, index = False, startrow = start_row, header = True)
